# %%
# Make sure you have a GPU running
# !nvidia-smi
# Out:
# Sun Jan 16 11:13:22 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.46       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# Install the latest release of Haystack in your own environment 
#! pip install farm-haystack

# Install the latest master of Haystack
# !pip install grpcio-tools==1.34.1
# !pip install git+https://github.com/deepset-ai/haystack.git

# If you run this notebook on Google Colab, you might need to
# restart the runtime after installing haystack.
# Out:
# Collecting grpcio-tools==1.34.1
#   Downloading grpcio_tools-1.34.1-cp37-cp37m-manylinux2014_x86_64.whl (2.5 MB)
#      |████████████████████████████████| 2.5 MB 5.2 MB/s
# Requirement already satisfied: grpcio>=1.34.1 in /usr/local/lib/python3.7/dist-packages (from grpcio-tools==1.34.1) (1.43.0)
# Requirement already satisfied: protobuf<4.0dev,>=3.5.0.post1 in /usr/local/lib/python3.7/dist-packages (from grpcio-tools==1.34.1) (3.17.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from grpcio-tools==1.34.1) (57.4.0)
# Requirement already satisfied: six>=1.5.2 in /usr/local/lib/python3.7/dist-packages (from grpcio>=1.34.1->grpcio-tools==1.34.1) (1.15.0)
# Installing collected packages: grpcio-tools
# Successfully installed grpcio-tools-1.34.1
# Collecting git+https://github.com/deepset-ai/haystack.git
#   Cloning https://github.com/deepset-ai/haystack.git to /tmp/pip-req-build-eytpmsno
#   Running command git clone -q https://github.com/deepset-ai/haystack.git /tmp/pip-req-build-eytpmsno
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from farm-haystack==1.0.0) (57.4.0)
# Requirement already satisfied: wheel in /usr/local/lib/python3.7/dist-packages (from farm-haystack==1.0.0) (0.37.1)
# Requirement already satisfied: torch<1.11,>1.9 in /usr/local/lib/python3.7/dist-packages (from farm-haystack==1.0.0) (1.10.0+cu111)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from farm-haystack==1.0.0) (4.62.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from farm-haystack==1.0.0) (2.23.0)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.7/dist-packages (from farm-haystack==1.0.0) (1.4.1)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from farm-haystack==1.0.0) (1.0.2)
# Collecting seqeval
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      |████████████████████████████████| 43 kB 1.1 MB/s
# Collecting mlflow<=1.13.1
#   Downloading mlflow-1.13.1-py3-none-any.whl (14.1 MB)
#      |████████████████████████████████| 14.1 MB 40 kB/s
# Collecting transformers==4.13.0
#   Downloading transformers-4.13.0-py3-none-any.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 48.2 MB/s
# Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from farm-haystack==1.0.0) (0.3.4)
# Requirement already satisfied: psutil in /usr/local/lib/python3.7/dist-packages (from farm-haystack==1.0.0) (5.4.8)
# Collecting fastapi
#   Downloading fastapi-0.71.0-py3-none-any.whl (51 kB)
#      |████████████████████████████████| 51 kB 782 kB/s
# Collecting uvicorn
#   Downloading uvicorn-0.17.0-py3-none-any.whl (54 kB)
#      |████████████████████████████████| 54 kB 3.8 MB/s
# Collecting gunicorn
#   Downloading gunicorn-20.1.0-py3-none-any.whl (79 kB)
#      |████████████████████████████████| 79 kB 8.9 MB/s
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from farm-haystack==1.0.0) (1.1.5)
# Collecting elasticsearch<=7.10,>=7.7
#   Downloading elasticsearch-7.10.0-py2.py3-none-any.whl (321 kB)
#      |████████████████████████████████| 321 kB 62.9 MB/s
# Collecting elastic-apm
#   Downloading elastic_apm-6.7.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (359 kB)
#      |████████████████████████████████| 359 kB 65.0 MB/s
# Collecting tox
#   Downloading tox-3.24.5-py2.py3-none-any.whl (85 kB)
#      |████████████████████████████████| 85 kB 4.0 MB/s
# Requirement already satisfied: coverage in /usr/local/lib/python3.7/dist-packages (from farm-haystack==1.0.0) (3.7.1)
# Collecting langdetect
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      |████████████████████████████████| 981 kB 52.1 MB/s
# Collecting pytesseract==0.3.7
#   Downloading pytesseract-0.3.7.tar.gz (13 kB)
# Collecting pillow==9.0.0
#   Downloading Pillow-9.0.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.3 MB)
#      |████████████████████████████████| 4.3 MB 43.8 MB/s
# Collecting pdf2image==1.14.0
#   Downloading pdf2image-1.14.0-py3-none-any.whl (10 kB)
# Collecting sentence-transformers>=0.4.0
#   Downloading sentence-transformers-2.1.0.tar.gz (78 kB)
#      |████████████████████████████████| 78 kB 5.6 MB/s
# Collecting python-multipart
#   Downloading python-multipart-0.0.5.tar.gz (32 kB)
# Collecting python-docx
#   Downloading python-docx-0.8.11.tar.gz (5.6 MB)
#      |████████████████████████████████| 5.6 MB 49.6 MB/s
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.7/dist-packages (from farm-haystack==1.0.0) (1.4.29)
# Collecting sqlalchemy_utils
#   Downloading SQLAlchemy_Utils-0.38.2-py3-none-any.whl (100 kB)
#      |████████████████████████████████| 100 kB 11.6 MB/s
# Collecting faiss-cpu>=1.6.3
#   Downloading faiss_cpu-1.7.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.6 MB)
#      |████████████████████████████████| 8.6 MB 24.3 MB/s
# Collecting tika
#   Downloading tika-1.24.tar.gz (28 kB)
# Collecting httptools
#   Downloading httptools-0.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (402 kB)
#      |████████████████████████████████| 402 kB 56.3 MB/s
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from farm-haystack==1.0.0) (3.2.5)
# Requirement already satisfied: more_itertools in /usr/local/lib/python3.7/dist-packages (from farm-haystack==1.0.0) (8.12.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.7/dist-packages (from farm-haystack==1.0.0) (2.6.3)
# Collecting pymilvus
#   Downloading pymilvus-1.1.2-py3-none-any.whl (56 kB)
#      |████████████████████████████████| 56 kB 4.9 MB/s
# Collecting SPARQLWrapper
#   Downloading SPARQLWrapper-1.8.5-py3-none-any.whl (26 kB)
# Collecting mmh3
#   Downloading mmh3-3.0.0-cp37-cp37m-manylinux2010_x86_64.whl (50 kB)
#      |████████████████████████████████| 50 kB 7.7 MB/s
# Collecting weaviate-client==2.5.0
#   Downloading weaviate_client-2.5.0-py3-none-any.whl (56 kB)
#      |████████████████████████████████| 56 kB 5.3 MB/s
# Collecting ray>=1.9.1
#   Downloading ray-1.9.2-cp37-cp37m-manylinux2014_x86_64.whl (57.6 MB)
#      |████████████████████████████████| 57.6 MB 1.2 MB/s
# Collecting dataclasses-json
#   Downloading dataclasses_json-0.5.6-py3-none-any.whl (25 kB)
# Collecting quantulum3
#   Downloading quantulum3-0.7.9-py3-none-any.whl (10.7 MB)
#      |████████████████████████████████| 10.7 MB 32.9 MB/s
# Collecting azure-ai-formrecognizer==3.2.0b2
#   Downloading azure_ai_formrecognizer-3.2.0b2-py2.py3-none-any.whl (219 kB)
#      |████████████████████████████████| 219 kB 50.9 MB/s
# Collecting psycopg2-binary
#   Downloading psycopg2_binary-2.9.3-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#      |████████████████████████████████| 3.0 MB 58.7 MB/s
# Collecting uvloop==0.14
#   Downloading uvloop-0.14.0-cp37-cp37m-manylinux2010_x86_64.whl (3.8 MB)
#      |████████████████████████████████| 3.8 MB 40.5 MB/s
# Requirement already satisfied: six>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from azure-ai-formrecognizer==3.2.0b2->farm-haystack==1.0.0) (1.15.0)
# Collecting azure-core<2.0.0,>=1.13.0
#   Downloading azure_core-1.21.1-py2.py3-none-any.whl (178 kB)
#      |████████████████████████████████| 178 kB 64.3 MB/s
# Collecting azure-common~=1.1
#   Downloading azure_common-1.1.27-py2.py3-none-any.whl (12 kB)
# Collecting msrest>=0.6.21
#   Downloading msrest-0.6.21-py2.py3-none-any.whl (85 kB)
#      |████████████████████████████████| 85 kB 4.6 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers==4.13.0->farm-haystack==1.0.0) (2019.12.20)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers==4.13.0->farm-haystack==1.0.0) (3.4.2)
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading tokenizers-0.10.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 62.7 MB/s
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers==4.13.0->farm-haystack==1.0.0) (21.3)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 60.9 MB/s
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.4.0-py3-none-any.whl (67 kB)
#      |████████████████████████████████| 67 kB 6.2 MB/s
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers==4.13.0->farm-haystack==1.0.0) (4.10.0)
# Collecting sacremoses
#   Downloading sacremoses-0.0.47-py2.py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 59.7 MB/s
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers==4.13.0->farm-haystack==1.0.0) (1.19.5)
# Collecting validators>=0.18.2
#   Downloading validators-0.18.2-py3-none-any.whl (19 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from elasticsearch<=7.10,>=7.7->farm-haystack==1.0.0) (2021.10.8)
# Requirement already satisfied: urllib3<2,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from elasticsearch<=7.10,>=7.7->farm-haystack==1.0.0) (1.24.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers==4.13.0->farm-haystack==1.0.0) (3.10.0.2)
# Collecting prometheus-flask-exporter
#   Downloading prometheus_flask_exporter-0.18.7-py3-none-any.whl (17 kB)
# Collecting querystring-parser
#   Downloading querystring_parser-1.2.4-py2.py3-none-any.whl (7.9 kB)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.7/dist-packages (from mlflow<=1.13.1->farm-haystack==1.0.0) (0.3)
# Collecting alembic<=1.4.1
#   Downloading alembic-1.4.1.tar.gz (1.1 MB)
#      |████████████████████████████████| 1.1 MB 70.3 MB/s
# Collecting databricks-cli>=0.8.7
#   Downloading databricks-cli-0.16.2.tar.gz (58 kB)
#      |████████████████████████████████| 58 kB 6.1 MB/s
# Requirement already satisfied: sqlparse>=0.3.1 in /usr/local/lib/python3.7/dist-packages (from mlflow<=1.13.1->farm-haystack==1.0.0) (0.4.2)
# Requirement already satisfied: protobuf>=3.6.0 in /usr/local/lib/python3.7/dist-packages (from mlflow<=1.13.1->farm-haystack==1.0.0) (3.17.3)
# Collecting docker>=4.0.0
#   Downloading docker-5.0.3-py2.py3-none-any.whl (146 kB)
#      |████████████████████████████████| 146 kB 63.6 MB/s
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.7/dist-packages (from mlflow<=1.13.1->farm-haystack==1.0.0) (7.1.2)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from mlflow<=1.13.1->farm-haystack==1.0.0) (2.8.2)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.7/dist-packages (from mlflow<=1.13.1->farm-haystack==1.0.0) (1.3.0)
# Collecting azure-storage-blob>=12.0.0
#   Downloading azure_storage_blob-12.9.0-py2.py3-none-any.whl (356 kB)
#      |████████████████████████████████| 356 kB 60.6 MB/s
# Requirement already satisfied: Flask in /usr/local/lib/python3.7/dist-packages (from mlflow<=1.13.1->farm-haystack==1.0.0) (1.1.4)
# Collecting gitpython>=2.1.0
#   Downloading GitPython-3.1.26-py3-none-any.whl (180 kB)
#      |████████████████████████████████| 180 kB 66.5 MB/s
# Collecting Mako
#   Downloading Mako-1.1.6-py2.py3-none-any.whl (75 kB)
#      |████████████████████████████████| 75 kB 5.5 MB/s
# Collecting python-editor>=0.3
#   Downloading python_editor-1.0.4-py3-none-any.whl (4.9 kB)
# Collecting cryptography>=2.1.4
#   Downloading cryptography-36.0.1-cp36-abi3-manylinux_2_24_x86_64.whl (3.6 MB)
#      |████████████████████████████████| 3.6 MB 47.7 MB/s
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.7/dist-packages (from cryptography>=2.1.4->azure-storage-blob>=12.0.0->mlflow<=1.13.1->farm-haystack==1.0.0) (1.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.12->cryptography>=2.1.4->azure-storage-blob>=12.0.0->mlflow<=1.13.1->farm-haystack==1.0.0) (2.21)
# Requirement already satisfied: tabulate>=0.7.7 in /usr/local/lib/python3.7/dist-packages (from databricks-cli>=0.8.7->mlflow<=1.13.1->farm-haystack==1.0.0) (0.8.9)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-1.2.3-py3-none-any.whl (53 kB)
#      |████████████████████████████████| 53 kB 1.7 MB/s
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.9-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 1.7 MB/s
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#      |████████████████████████████████| 41 kB 625 kB/s
# Requirement already satisfied: requests-oauthlib>=0.5.0 in /usr/local/lib/python3.7/dist-packages (from msrest>=0.6.21->azure-ai-formrecognizer==3.2.0b2->farm-haystack==1.0.0) (1.3.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers==4.13.0->farm-haystack==1.0.0) (3.0.6)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.7/dist-packages (from ray>=1.9.1->farm-haystack==1.0.0) (4.3.3)
# Requirement already satisfied: attrs in /usr/local/lib/python3.7/dist-packages (from ray>=1.9.1->farm-haystack==1.0.0) (21.4.0)
# Requirement already satisfied: grpcio>=1.28.1 in /usr/local/lib/python3.7/dist-packages (from ray>=1.9.1->farm-haystack==1.0.0) (1.43.0)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from ray>=1.9.1->farm-haystack==1.0.0) (1.0.3)
# Collecting redis>=3.5.0
#   Downloading redis-4.1.0-py3-none-any.whl (171 kB)
#      |████████████████████████████████| 171 kB 64.8 MB/s
# Collecting deprecated>=1.2.3
#   Downloading Deprecated-1.2.13-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.7/dist-packages (from deprecated>=1.2.3->redis>=3.5.0->ray>=1.9.1->farm-haystack==1.0.0) (1.13.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers==4.13.0->farm-haystack==1.0.0) (3.7.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->farm-haystack==1.0.0) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->farm-haystack==1.0.0) (2.10)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.5.0->msrest>=0.6.21->azure-ai-formrecognizer==3.2.0b2->farm-haystack==1.0.0) (3.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=1.0.0->farm-haystack==1.0.0) (3.0.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=1.0.0->farm-haystack==1.0.0) (1.1.0)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from sentence-transformers>=0.4.0->farm-haystack==1.0.0) (0.11.1+cu111)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 41.5 MB/s
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.7/dist-packages (from sqlalchemy>=1.4.2->farm-haystack==1.0.0) (1.1.2)
# Requirement already satisfied: decorator>=3.4.0 in /usr/local/lib/python3.7/dist-packages (from validators>=0.18.2->weaviate-client==2.5.0->farm-haystack==1.0.0) (4.4.2)
# Collecting marshmallow<4.0.0,>=3.3.0
#   Downloading marshmallow-3.14.1-py3-none-any.whl (47 kB)
#      |████████████████████████████████| 47 kB 5.3 MB/s
# Collecting typing-inspect>=0.4.0
#   Downloading typing_inspect-0.7.1-py3-none-any.whl (8.4 kB)
# Collecting marshmallow-enum<2.0.0,>=1.5.1
#   Downloading marshmallow_enum-1.5.1-py2.py3-none-any.whl (4.2 kB)
# Collecting mypy-extensions>=0.3.0
#   Downloading mypy_extensions-0.4.3-py2.py3-none-any.whl (4.5 kB)
# Collecting starlette==0.17.1
#   Downloading starlette-0.17.1-py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 6.7 MB/s
# Collecting pydantic!=1.7,!=1.7.1,!=1.7.2,!=1.7.3,!=1.8,!=1.8.1,<2.0.0,>=1.6.2
#   Downloading pydantic-1.9.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.9 MB)
#      |████████████████████████████████| 10.9 MB 48.9 MB/s
# Collecting anyio<4,>=3.0.0
#   Downloading anyio-3.5.0-py3-none-any.whl (79 kB)
#      |████████████████████████████████| 79 kB 9.3 MB/s
# Collecting sniffio>=1.1
#   Downloading sniffio-1.2.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: Werkzeug<2.0,>=0.15 in /usr/local/lib/python3.7/dist-packages (from Flask->mlflow<=1.13.1->farm-haystack==1.0.0) (1.0.1)
# Requirement already satisfied: Jinja2<3.0,>=2.10.1 in /usr/local/lib/python3.7/dist-packages (from Flask->mlflow<=1.13.1->farm-haystack==1.0.0) (2.11.3)
# Requirement already satisfied: itsdangerous<2.0,>=0.24 in /usr/local/lib/python3.7/dist-packages (from Flask->mlflow<=1.13.1->farm-haystack==1.0.0) (1.1.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2<3.0,>=2.10.1->Flask->mlflow<=1.13.1->farm-haystack==1.0.0) (2.0.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema->ray>=1.9.1->farm-haystack==1.0.0) (0.18.0)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema->ray>=1.9.1->farm-haystack==1.0.0) (5.4.0)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->farm-haystack==1.0.0) (2018.9)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.7/dist-packages (from prometheus-flask-exporter->mlflow<=1.13.1->farm-haystack==1.0.0) (0.12.0)
# Collecting ujson>=2.0.0
#   Downloading ujson-5.1.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (43 kB)
#      |████████████████████████████████| 43 kB 2.5 MB/s
# Collecting grpcio>=1.28.1
#   Downloading grpcio-1.37.1-cp37-cp37m-manylinux2014_x86_64.whl (4.2 MB)
#      |████████████████████████████████| 4.2 MB 49.3 MB/s
# Requirement already satisfied: grpcio-tools<1.38.0,>=1.22.0 in /usr/local/lib/python3.7/dist-packages (from pymilvus->farm-haystack==1.0.0) (1.34.1)
# Requirement already satisfied: lxml>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from python-docx->farm-haystack==1.0.0) (4.2.6)
# Requirement already satisfied: inflect in /usr/local/lib/python3.7/dist-packages (from quantulum3->farm-haystack==1.0.0) (2.1.0)
# Collecting num2words
#   Downloading num2words-0.5.10-py3-none-any.whl (101 kB)
#      |████████████████████████████████| 101 kB 13.9 MB/s
# Requirement already satisfied: docopt>=0.6.2 in /usr/local/lib/python3.7/dist-packages (from num2words->quantulum3->farm-haystack==1.0.0) (0.6.2)
# Collecting rdflib>=4.0
#   Downloading rdflib-6.1.1-py3-none-any.whl (482 kB)
#      |████████████████████████████████| 482 kB 62.6 MB/s
# Requirement already satisfied: py>=1.4.17 in /usr/local/lib/python3.7/dist-packages (from tox->farm-haystack==1.0.0) (1.11.0)
# Collecting pluggy>=0.12.0
#   Downloading pluggy-1.0.0-py2.py3-none-any.whl (13 kB)
# Collecting virtualenv!=20.0.0,!=20.0.1,!=20.0.2,!=20.0.3,!=20.0.4,!=20.0.5,!=20.0.6,!=20.0.7,>=16.0.0
#   Downloading virtualenv-20.13.0-py2.py3-none-any.whl (6.5 MB)
#      |████████████████████████████████| 6.5 MB 53.8 MB/s
# Requirement already satisfied: toml>=0.9.4 in /usr/local/lib/python3.7/dist-packages (from tox->farm-haystack==1.0.0) (0.10.2)
# Collecting platformdirs<3,>=2
#   Downloading platformdirs-2.4.1-py3-none-any.whl (14 kB)
# Collecting distlib<1,>=0.3.1
#   Downloading distlib-0.3.4-py2.py3-none-any.whl (461 kB)
#      |████████████████████████████████| 461 kB 63.5 MB/s
# Collecting asgiref>=3.4.0
#   Downloading asgiref-3.4.1-py3-none-any.whl (25 kB)
# Collecting h11>=0.8
#   Downloading h11-0.12.0-py3-none-any.whl (54 kB)
#      |████████████████████████████████| 54 kB 3.6 MB/s
# Building wheels for collected packages: farm-haystack, pytesseract, alembic, databricks-cli, sentence-transformers, langdetect, python-docx, python-multipart, seqeval, tika
#   Building wheel for farm-haystack (setup.py) ... done
#   Created wheel for farm-haystack: filename=farm_haystack-1.0.0-py3-none-any.whl size=392702 sha256=e9227deca0bc90c11fac1cc4596714c8b8639bf309796d0f78782ff9a633b7f5
#   Stored in directory: /tmp/pip-ephem-wheel-cache-wrk64he5/wheels/a7/05/3b/9b33368d9af06a39f8e6af2e97fa2af876e893ade323cfc2c9
#   Building wheel for pytesseract (setup.py) ... done
#   Created wheel for pytesseract: filename=pytesseract-0.3.7-py2.py3-none-any.whl size=13954 sha256=9597cc1cf637b2e3f5b5fae4aa2bcdd82bd342943f6ed820f96506885d7034dd
#   Stored in directory: /root/.cache/pip/wheels/67/71/6c/7a8c5ca2e699752506999ae7baeb692e2b4fc6488c2cddcb22
#   Building wheel for alembic (setup.py) ... done
#   Created wheel for alembic: filename=alembic-1.4.1-py2.py3-none-any.whl size=158171 sha256=a111e2c8c96ddf9bac2b18258b83c76f58ae8b43c70ed3049f6316e202136ce3
#   Stored in directory: /root/.cache/pip/wheels/be/5d/0a/9e13f53f4f5dfb67cd8d245bb7cdffe12f135846f491a283e3
#   Building wheel for databricks-cli (setup.py) ... done
#   Created wheel for databricks-cli: filename=databricks_cli-0.16.2-py3-none-any.whl size=106811 sha256=6cdfb41ec794099b98c2fc239131cd8c9412dd97def482e450831c60dfa0ab61
#   Stored in directory: /root/.cache/pip/wheels/f4/5c/ed/e1ce20a53095f63b27b4964abbad03e59cf3472822addf7d29
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.1.0-py3-none-any.whl size=120999 sha256=a9e6839fbc112ba3da1e03534064aa15c9610b2575807dc8b600ca28d54254b5
#   Stored in directory: /root/.cache/pip/wheels/90/f0/bb/ed1add84da70092ea526466eadc2bfb197c4bcb8d4fa5f7bad
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993242 sha256=f45fcb3750fde04436846ddd5739b3a6897bdea6f316dbcb4d6910d3e7d592dd
#   Stored in directory: /root/.cache/pip/wheels/c5/96/8a/f90c59ed25d75e50a8c10a1b1c2d4c402e4dacfa87f3aff36a
#   Building wheel for python-docx (setup.py) ... done
#   Created wheel for python-docx: filename=python_docx-0.8.11-py3-none-any.whl size=184507 sha256=0e38396f3a20d94e97308b1d446311036e53dcac802261a4665fbe5eb1cc4d7b
#   Stored in directory: /root/.cache/pip/wheels/f6/6f/b9/d798122a8b55b74ad30b5f52b01482169b445fbb84a11797a6
#   Building wheel for python-multipart (setup.py) ... done
#   Created wheel for python-multipart: filename=python_multipart-0.0.5-py3-none-any.whl size=31678 sha256=88f4e4036182686c61d7fd78818d160245c4e3026bd666c44fb13743d37306f6
#   Stored in directory: /root/.cache/pip/wheels/2c/41/7c/bfd1c180534ffdcc0972f78c5758f89881602175d48a8bcd2c
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16180 sha256=76e251c5102729de74f8abe46c0d358ae4027cd483e5f1062dda61475fc46493
#   Stored in directory: /root/.cache/pip/wheels/05/96/ee/7cac4e74f3b19e3158dce26a20a1c86b3533c43ec72a549fd7
#   Building wheel for tika (setup.py) ... done
#   Created wheel for tika: filename=tika-1.24-py3-none-any.whl size=32893 sha256=88559662fe44531c9aba61b76753ce4c5c534bb60818b4d17e651d8a9fc67c18
#   Stored in directory: /root/.cache/pip/wheels/ec/2b/38/58ff05467a742e32f67f5d0de048fa046e764e2fbb25ac93f3
# Successfully built farm-haystack pytesseract alembic databricks-cli sentence-transformers langdetect python-docx python-multipart seqeval tika
# Installing collected packages: sniffio, smmap, pyyaml, isodate, websocket-client, tokenizers, sacremoses, python-editor, platformdirs, pillow, mypy-extensions, msrest, marshmallow, Mako, huggingface-hub, grpcio, gitdb, distlib, deprecated, cryptography, azure-core, anyio, virtualenv, validators, ujson, typing-inspect, transformers, starlette, sentencepiece, redis, rdflib, querystring-parser, pydantic, prometheus-flask-exporter, pluggy, num2words, marshmallow-enum, h11, gunicorn, gitpython, docker, databricks-cli, azure-storage-blob, azure-common, asgiref, alembic, weaviate-client, uvloop, uvicorn, tox, tika, sqlalchemy-utils, SPARQLWrapper, seqeval, sentence-transformers, ray, quantulum3, python-multipart, python-docx, pytesseract, pymilvus, psycopg2-binary, pdf2image, mmh3, mlflow, langdetect, httptools, fastapi, faiss-cpu, elasticsearch, elastic-apm, dataclasses-json, azure-ai-formrecognizer, farm-haystack
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
#   Attempting uninstall: pillow
#     Found existing installation: Pillow 7.1.2
#     Uninstalling Pillow-7.1.2:
#       Successfully uninstalled Pillow-7.1.2
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.43.0
#     Uninstalling grpcio-1.43.0:
#       Successfully uninstalled grpcio-1.43.0
#   Attempting uninstall: pluggy
#     Found existing installation: pluggy 0.7.1
#     Uninstalling pluggy-0.7.1:
#       Successfully uninstalled pluggy-0.7.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pytest 3.6.4 requires pluggy<0.8,>=0.5, but you have pluggy 1.0.0 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed Mako-1.1.6 SPARQLWrapper-1.8.5 alembic-1.4.1 anyio-3.5.0 asgiref-3.4.1 azure-ai-formrecognizer-3.2.0b2 azure-common-1.1.27 azure-core-1.21.1 azure-storage-blob-12.9.0 cryptography-36.0.1 databricks-cli-0.16.2 dataclasses-json-0.5.6 deprecated-1.2.13 distlib-0.3.4 docker-5.0.3 elastic-apm-6.7.2 elasticsearch-7.10.0 faiss-cpu-1.7.2 farm-haystack-1.0.0 fastapi-0.71.0 gitdb-4.0.9 gitpython-3.1.26 grpcio-1.37.1 gunicorn-20.1.0 h11-0.12.0 httptools-0.3.0 huggingface-hub-0.4.0 isodate-0.6.1 langdetect-1.0.9 marshmallow-3.14.1 marshmallow-enum-1.5.1 mlflow-1.13.1 mmh3-3.0.0 msrest-0.6.21 mypy-extensions-0.4.3 num2words-0.5.10 pdf2image-1.14.0 pillow-9.0.0 platformdirs-2.4.1 pluggy-1.0.0 prometheus-flask-exporter-0.18.7 psycopg2-binary-2.9.3 pydantic-1.9.0 pymilvus-1.1.2 pytesseract-0.3.7 python-docx-0.8.11 python-editor-1.0.4 python-multipart-0.0.5 pyyaml-6.0 quantulum3-0.7.9 querystring-parser-1.2.4 ray-1.9.2 rdflib-6.1.1 redis-4.1.0 sacremoses-0.0.47 sentence-transformers-2.1.0 sentencepiece-0.1.96 seqeval-1.2.2 smmap-5.0.0 sniffio-1.2.0 sqlalchemy-utils-0.38.2 starlette-0.17.1 tika-1.24 tokenizers-0.10.3 tox-3.24.5 transformers-4.13.0 typing-inspect-0.7.1 ujson-5.1.0 uvicorn-0.17.0 uvloop-0.14.0 validators-0.18.2 virtualenv-20.13.0 weaviate-client-2.5.0 websocket-client-1.2.3

# %%
from haystack.utils import clean_wiki_text, convert_files_to_dicts, fetch_archive_from_http, print_answers
from haystack.nodes import FARMReader, TransformersReader

# %% [markdown]
# ## Document Store

# %%
# Recommended: Start Elasticsearch using Docker via the Haystack utility function
from haystack.utils import launch_es

launch_es()
# Out:
# WARNING - haystack.utils.doc_store -  Tried to start Elasticsearch through Docker but this failed. It is likely that there is already an existing Elasticsearch instance running.

# %%
# In Colab / No Docker environments: Start Elasticsearch from source
! wget https://artifacts.elastic.co/downloads/elasticsearch/elasticsearch-7.9.2-linux-x86_64.tar.gz -q
! tar -xzf elasticsearch-7.9.2-linux-x86_64.tar.gz
! chown -R daemon:daemon elasticsearch-7.9.2

import os
from subprocess import Popen, PIPE, STDOUT
es_server = Popen(['elasticsearch-7.9.2/bin/elasticsearch'],
                   stdout=PIPE, stderr=STDOUT,
                   preexec_fn=lambda: os.setuid(1)  # as daemon
                  )
# wait until ES has started
! sleep 30

# %%
# Connect to Elasticsearch

from haystack.document_stores import ElasticsearchDocumentStore

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Creation of document stores

# %%
reg_document_store = ElasticsearchDocumentStore(host="localhost", username="", password="", index="document")
legal_document_store = ElasticsearchDocumentStore(host="localhost", username="", password="", index="document")
misc_document_store = ElasticsearchDocumentStore(host="localhost", username="", password="", index="document")

import pickle

with open("/content/drive/MyDrive/CollabData/RegulationElasticDict.pkl","rb") as f:
  dicts = pickle.load(f)

reg_document_store.write_documents(dicts)

with open("/content/drive/MyDrive/CollabData/CaseElasticDict.pkl","rb") as f:
  dicts = pickle.load(f)

legal_document_store.write_documents(dicts)

with open("/content/drive/MyDrive/CollabData/MiscElasticDict.pkl","rb") as f:
  dicts = pickle.load(f)

misc_document_store.write_documents(dicts)

# %%
# Document Stores with 512 size chunks

reg_document_store = ElasticsearchDocumentStore(host="localhost", username="", password="", index="document")
legal_document_store = ElasticsearchDocumentStore(host="localhost", username="", password="", index="document")
misc_document_store = ElasticsearchDocumentStore(host="localhost", username="", password="", index="document")

import pickle

with open("/content/drive/MyDrive/CollabData/Regulation512ElasticDict.pkl","rb") as f:
  dicts = pickle.load(f)

reg_document_store.write_documents(dicts)

with open("/content/drive/MyDrive/CollabData/Case512ElasticDict.pkl","rb") as f:
  dicts = pickle.load(f)

legal_document_store.write_documents(dicts)

with open("/content/drive/MyDrive/CollabData/Misc512ElasticDict.pkl","rb") as f:
  dicts = pickle.load(f)

misc_document_store.write_documents(dicts)

# %% [markdown]
# ## Initalize Retriever, Reader,  & Pipeline

# %%
from haystack.nodes import ElasticsearchRetriever

# Alternatives are 
# from haystack.nodes import TfidfRetriever
# from haystack.nodes import EmbeddingRetriever

reg_retriever = ElasticsearchRetriever(document_store=reg_document_store)
legal_retriever = ElasticsearchRetriever(document_store=legal_document_store)
misc_retriever = ElasticsearchRetriever(document_store=misc_document_store)

# reg_retriever = TfidfRetriever(document_store=reg_document_store)
# legal_retriever = TfidfRetriever(document_store=legal_document_store)
# misc_retriever = TfidfRetriever(document_store=misc_document_store)

# reg_retriever = EmbeddingRetriever(document_store=reg_document_store,embedding_model="sentence-transformers/bert-base-nli-mean-tokens")
# legal_retriever = EmbeddingRetriever(document_store=legal_document_store,embedding_model="sentence-transformers/bert-base-nli-mean-tokens")
# misc_retriever = EmbeddingRetriever(document_store=misc_document_store,embedding_model="sentence-transformers/bert-base-nli-mean-tokens")

# %%
reg_document_store.update_embeddings(reg_retriever)

legal_document_store.update_embeddings(legal_retriever)

misc_document_store.update_embeddings(misc_retriever)
# Out:
# INFO - haystack.document_stores.elasticsearch -  Updating embeddings for all 19352 docs ...
# Updating embeddings:   0%|          | 0/19352 [00:00<?, ? Docs/s]
# Inferencing Samples:   0%|          | 0/313 [00:00<?, ? Batches/s]
# Inferencing Samples:   0%|          | 1/313 [00:02<14:03,  2.70s/ Batches]
# Inferencing Samples:   1%|          | 2/313 [00:05<13:52,  2.68s/ Batches]
# Inferencing Samples:   1%|          | 3/313 [00:08<13:46,  2.67s/ Batches]
# Inferencing Samples:   1%|▏         | 4/313 [00:10<13:44,  2.67s/ Batches]
# Inferencing Samples:   2%|▏         | 5/313 [00:13<13:41,  2.67s/ Batches]
# Inferencing Samples:   2%|▏         | 6/313 [00:16<13:38,  2.67s/ Batches]
# Inferencing Samples:   2%|▏         | 7/313 [00:18<13:35,  2.66s/ Batches]
# Inferencing Samples:   3%|▎         | 8/313 [00:21<13:32,  2.66s/ Batches]
# Inferencing Samples:   3%|▎         | 9/313 [00:23<13:28,  2.66s/ Batches]
# Inferencing Samples:   3%|▎         | 10/313 [00:26<13:26,  2.66s/ Batches]
# Inferencing Samples:   4%|▎         | 11/313 [00:29<13:23,  2.66s/ Batches]
# Inferencing Samples:   4%|▍         | 12/313 [00:31<13:21,  2.66s/ Batches]
# Inferencing Samples:   4%|▍         | 13/313 [00:34<13:17,  2.66s/ Batches]
# Inferencing Samples:   4%|▍         | 14/313 [00:37<13:15,  2.66s/ Batches]
# Inferencing Samples:   5%|▍         | 15/313 [00:39<13:12,  2.66s/ Batches]
# Inferencing Samples:   5%|▌         | 16/313 [00:42<13:10,  2.66s/ Batches]
# Inferencing Samples:   5%|▌         | 17/313 [00:45<13:08,  2.66s/ Batches]
# Inferencing Samples:   6%|▌         | 18/313 [00:47<13:05,  2.66s/ Batches]
# Inferencing Samples:   6%|▌         | 19/313 [00:50<13:02,  2.66s/ Batches]
# Inferencing Samples:   6%|▋         | 20/313 [00:53<12:59,  2.66s/ Batches]
# Inferencing Samples:   7%|▋         | 21/313 [00:55<12:56,  2.66s/ Batches]
# Inferencing Samples:   7%|▋         | 22/313 [00:58<12:55,  2.66s/ Batches]
# Inferencing Samples:   7%|▋         | 23/313 [01:01<12:52,  2.66s/ Batches]
# Inferencing Samples:   8%|▊         | 24/313 [01:03<12:49,  2.66s/ Batches]
# Inferencing Samples:   8%|▊         | 25/313 [01:06<12:46,  2.66s/ Batches]
# Inferencing Samples:   8%|▊         | 26/313 [01:09<12:44,  2.66s/ Batches]
# Inferencing Samples:   9%|▊         | 27/313 [01:11<12:42,  2.66s/ Batches]
# Inferencing Samples:   9%|▉         | 28/313 [01:14<12:38,  2.66s/ Batches]
# Inferencing Samples:  53%|█████▎    | 167/313 [07:24<06:28,  2.66s/ Batches]
# Inferencing Samples:  54%|█████▎    | 168/313 [07:27<06:25,  2.66s/ Batches]
# Inferencing Samples:  54%|█████▍    | 169/313 [07:29<06:23,  2.66s/ Batches]
# Inferencing Samples:  54%|█████▍    | 170/313 [07:32<06:20,  2.66s/ Batches]
# Inferencing Samples:  55%|█████▍    | 171/313 [07:35<06:17,  2.66s/ Batches]
# Inferencing Samples:  55%|█████▍    | 172/313 [07:37<06:15,  2.66s/ Batches]
# Inferencing Samples:  55%|█████▌    | 173/313 [07:40<06:12,  2.66s/ Batches]
# Inferencing Samples:  56%|█████▌    | 174/313 [07:43<06:09,  2.66s/ Batches]
# Inferencing Samples:  56%|█████▌    | 175/313 [07:45<06:07,  2.66s/ Batches]
# Inferencing Samples:  56%|█████▌    | 176/313 [07:48<06:04,  2.66s/ Batches]
# Inferencing Samples:  57%|█████▋    | 177/313 [07:51<06:01,  2.66s/ Batches]
# Inferencing Samples:  57%|█████▋    | 178/313 [07:53<05:59,  2.66s/ Batches]
# Inferencing Samples:  57%|█████▋    | 179/313 [07:56<05:56,  2.66s/ Batches]
# Inferencing Samples:  58%|█████▊    | 180/313 [07:59<05:54,  2.66s/ Batches]
# Inferencing Samples:  58%|█████▊    | 181/313 [08:01<05:51,  2.66s/ Batches]
# Inferencing Samples:  58%|█████▊    | 182/313 [08:04<05:48,  2.66s/ Batches]
# Inferencing Samples:  58%|█████▊    | 183/313 [08:07<05:46,  2.66s/ Batches]
# Inferencing Samples:  59%|█████▉    | 184/313 [08:09<05:43,  2.66s/ Batches]
# Inferencing Samples:  59%|█████▉    | 185/313 [08:12<05:40,  2.66s/ Batches]
# Inferencing Samples:  59%|█████▉    | 186/313 [08:15<05:38,  2.66s/ Batches]
# Inferencing Samples:  60%|█████▉    | 187/313 [08:17<05:35,  2.66s/ Batches]
# Inferencing Samples:  60%|██████    | 188/313 [08:20<05:33,  2.66s/ Batches]
# Inferencing Samples:  60%|██████    | 189/313 [08:23<05:30,  2.66s/ Batches]
# Inferencing Samples:  61%|██████    | 190/313 [08:25<05:27,  2.66s/ Batches]
# Inferencing Samples:  61%|██████    | 191/313 [08:28<05:24,  2.66s/ Batches]
# Inferencing Samples:  61%|██████▏   | 192/313 [08:31<05:22,  2.66s/ Batches]
# Inferencing Samples:  62%|██████▏   | 193/313 [08:33<05:19,  2.66s/ Batches]
# Inferencing Samples:  62%|██████▏   | 194/313 [08:36<05:16,  2.66s/ Batches]
# Inferencing Samples:  62%|██████▏   | 195/313 [08:39<05:14,  2.66s/ Batches]
# Inferencing Samples:  63%|██████▎   | 196/313 [08:41<05:11,  2.66s/ Batches]
# Inferencing Samples:  63%|██████▎   | 197/313 [08:44<05:08,  2.66s/ Batches]
# Inferencing Samples:  63%|██████▎   | 198/313 [08:47<05:06,  2.66s/ Batches]
# Inferencing Samples:  64%|██████▎   | 199/313 [08:49<05:03,  2.66s/ Batches]
# Inferencing Samples:  85%|████████▌ | 267/313 [11:50<02:02,  2.66s/ Batches]
# Inferencing Samples:  86%|████████▌ | 268/313 [11:53<01:59,  2.66s/ Batches]
# Inferencing Samples:  86%|████████▌ | 269/313 [11:56<01:57,  2.66s/ Batches]
# Inferencing Samples:  86%|████████▋ | 270/313 [11:58<01:54,  2.66s/ Batches]
# Inferencing Samples:  87%|████████▋ | 271/313 [12:01<01:51,  2.66s/ Batches]
# Inferencing Samples:  87%|████████▋ | 272/313 [12:04<01:49,  2.66s/ Batches]
# Inferencing Samples:  87%|████████▋ | 273/313 [12:06<01:46,  2.66s/ Batches]
# Inferencing Samples:  88%|████████▊ | 274/313 [12:09<01:43,  2.66s/ Batches]
# Inferencing Samples:  88%|████████▊ | 275/313 [12:12<01:41,  2.66s/ Batches]
# Inferencing Samples:  88%|████████▊ | 276/313 [12:14<01:38,  2.66s/ Batches]
# Inferencing Samples:  88%|████████▊ | 277/313 [12:17<01:35,  2.66s/ Batches]
# Inferencing Samples:  89%|████████▉ | 278/313 [12:20<01:33,  2.66s/ Batches]
# Inferencing Samples:  89%|████████▉ | 279/313 [12:22<01:30,  2.66s/ Batches]
# Inferencing Samples:  89%|████████▉ | 280/313 [12:25<01:27,  2.66s/ Batches]
# Inferencing Samples:  90%|████████▉ | 281/313 [12:28<01:25,  2.66s/ Batches]
# Inferencing Samples:  90%|█████████ | 282/313 [12:30<01:22,  2.66s/ Batches]
# Inferencing Samples:  90%|█████████ | 283/313 [12:33<01:19,  2.66s/ Batches]
# Inferencing Samples:  91%|█████████ | 284/313 [12:36<01:17,  2.66s/ Batches]
# Inferencing Samples:  91%|█████████ | 285/313 [12:38<01:14,  2.66s/ Batches]
# Inferencing Samples:  91%|█████████▏| 286/313 [12:41<01:11,  2.66s/ Batches]
# Inferencing Samples:  92%|█████████▏| 287/313 [12:44<01:09,  2.66s/ Batches]
# Inferencing Samples:  92%|█████████▏| 288/313 [12:46<01:06,  2.66s/ Batches]
# Inferencing Samples:  92%|█████████▏| 289/313 [12:49<01:03,  2.66s/ Batches]
# Inferencing Samples:  93%|█████████▎| 290/313 [12:52<01:01,  2.66s/ Batches]
# Inferencing Samples:  93%|█████████▎| 291/313 [12:54<00:58,  2.66s/ Batches]
# Inferencing Samples:  93%|█████████▎| 292/313 [12:57<00:55,  2.66s/ Batches]
# Inferencing Samples:  94%|█████████▎| 293/313 [13:00<00:53,  2.66s/ Batches]
# Inferencing Samples:  94%|█████████▍| 294/313 [13:02<00:50,  2.66s/ Batches]
# Inferencing Samples:  94%|█████████▍| 295/313 [13:05<00:47,  2.66s/ Batches]
# Inferencing Samples:  95%|█████████▍| 296/313 [13:08<00:45,  2.66s/ Batches]
# Inferencing Samples:  95%|█████████▍| 297/313 [13:10<00:42,  2.66s/ Batches]
# Inferencing Samples:  95%|█████████▌| 298/313 [13:13<00:39,  2.66s/ Batches]
# Inferencing Samples:  96%|█████████▌| 299/313 [13:16<00:37,  2.66s/ Batches]
# Inferencing Samples:  96%|█████████▌| 300/313 [13:18<00:34,  2.66s/ Batches]
# Inferencing Samples:  96%|█████████▌| 301/313 [13:21<00:31,  2.66s/ Batches]
# Inferencing Samples:  96%|█████████▋| 302/313 [13:24<00:29,  2.66s/ Batches]
# Inferencing Samples:  97%|█████████▋| 303/313 [13:26<00:26,  2.66s/ Batches]
# Inferencing Samples:  97%|█████████▋| 304/313 [13:29<00:23,  2.66s/ Batches]
# Inferencing Samples:  97%|█████████▋| 305/313 [13:32<00:21,  2.66s/ Batches]
# Inferencing Samples:  98%|█████████▊| 306/313 [13:34<00:18,  2.66s/ Batches]
# Inferencing Samples:  98%|█████████▊| 307/313 [13:37<00:15,  2.67s/ Batches]
# Inferencing Samples:  98%|█████████▊| 308/313 [13:40<00:13,  2.67s/ Batches]
# Inferencing Samples:  99%|█████████▊| 309/313 [13:42<00:10,  2.66s/ Batches]
# Inferencing Samples:  99%|█████████▉| 310/313 [13:45<00:07,  2.66s/ Batches]
# Inferencing Samples:  99%|█████████▉| 311/313 [13:48<00:05,  2.66s/ Batches]
# Inferencing Samples: 100%|█████████▉| 312/313 [13:50<00:02,  2.66s/ Batches]
# Inferencing Samples: 100%|██████████| 313/313 [13:52<00:00,  2.66s/ Batches]
#
# Inferencing Samples:   0%|          | 0/293 [00:00<?, ? Batches/s]
# Inferencing Samples:   0%|          | 1/293 [00:02<13:14,  2.72s/ Batches]
# Inferencing Samples:   1%|          | 2/293 [00:05<13:01,  2.68s/ Batches]
# Inferencing Samples:   1%|          | 3/293 [00:08<12:54,  2.67s/ Batches]
# Inferencing Samples:   1%|▏         | 4/293 [00:10<12:50,  2.66s/ Batches]
# Inferencing Samples:   2%|▏         | 5/293 [00:13<12:46,  2.66s/ Batches]
# Inferencing Samples:   2%|▏         | 6/293 [00:16<12:43,  2.66s/ Batches]
# Inferencing Samples:   2%|▏         | 7/293 [00:18<12:40,  2.66s/ Batches]
# Inferencing Samples:   3%|▎         | 8/293 [00:21<12:38,  2.66s/ Batches]
# Inferencing Samples:   3%|▎         | 9/293 [00:23<12:35,  2.66s/ Batches]
# Inferencing Samples:   3%|▎         | 10/293 [00:26<12:32,  2.66s/ Batches]
# Inferencing Samples:   4%|▍         | 11/293 [00:29<12:30,  2.66s/ Batches]
# Inferencing Samples:   4%|▍         | 12/293 [00:31<12:27,  2.66s/ Batches]
# Inferencing Samples:   4%|▍         | 13/293 [00:34<12:25,  2.66s/ Batches]
# Inferencing Samples:   5%|▍         | 14/293 [00:37<12:22,  2.66s/ Batches]
# Inferencing Samples:   5%|▌         | 15/293 [00:39<12:20,  2.66s/ Batches]
# Inferencing Samples:   5%|▌         | 16/293 [00:42<12:18,  2.67s/ Batches]
# Inferencing Samples:   6%|▌         | 17/293 [00:45<12:15,  2.66s/ Batches]
# Inferencing Samples:   6%|▌         | 18/293 [00:47<12:13,  2.67s/ Batches]
# Inferencing Samples:   6%|▋         | 19/293 [00:50<12:09,  2.66s/ Batches]
# Inferencing Samples:   7%|▋         | 20/293 [00:53<12:07,  2.67s/ Batches]
# Inferencing Samples:   7%|▋         | 21/293 [00:55<12:04,  2.66s/ Batches]
# Inferencing Samples:   8%|▊         | 22/293 [00:58<12:01,  2.66s/ Batches]
# Inferencing Samples:   8%|▊         | 23/293 [01:01<11:59,  2.66s/ Batches]
# Inferencing Samples:   8%|▊         | 24/293 [01:03<11:57,  2.67s/ Batches]
# Inferencing Samples:   9%|▊         | 25/293 [01:06<11:54,  2.67s/ Batches]
# Inferencing Samples:   9%|▉         | 26/293 [01:09<11:52,  2.67s/ Batches]
# Inferencing Samples:   9%|▉         | 27/293 [01:11<11:49,  2.67s/ Batches]
# Inferencing Samples:  10%|▉         | 28/293 [01:14<11:46,  2.67s/ Batches]
# Inferencing Samples:  10%|▉         | 29/293 [01:17<11:43,  2.67s/ Batches]
# Inferencing Samples:  10%|█         | 30/293 [01:19<11:40,  2.66s/ Batches]
# Inferencing Samples:  11%|█         | 31/293 [01:22<11:38,  2.67s/ Batches]
# Inferencing Samples:  11%|█         | 32/293 [01:25<11:35,  2.67s/ Batches]
# Inferencing Samples:  11%|█▏        | 33/293 [01:27<11:32,  2.66s/ Batches]
# Inferencing Samples:  12%|█▏        | 34/293 [01:30<11:30,  2.66s/ Batches]
# Inferencing Samples:  12%|█▏        | 35/293 [01:33<11:27,  2.66s/ Batches]
# Inferencing Samples:  12%|█▏        | 36/293 [01:35<11:24,  2.66s/ Batches]
# Inferencing Samples:  13%|█▎        | 37/293 [01:38<11:22,  2.67s/ Batches]
# Inferencing Samples:  13%|█▎        | 38/293 [01:41<11:20,  2.67s/ Batches]
# Inferencing Samples:  13%|█▎        | 39/293 [01:43<11:17,  2.67s/ Batches]
# Inferencing Samples:  14%|█▎        | 40/293 [01:46<11:14,  2.67s/ Batches]
# Inferencing Samples:  14%|█▍        | 41/293 [01:49<11:11,  2.67s/ Batches]
# Inferencing Samples:  14%|█▍        | 42/293 [01:51<11:08,  2.66s/ Batches]
# Inferencing Samples:  15%|█▍        | 43/293 [01:54<11:06,  2.67s/ Batches]
# Inferencing Samples:  15%|█▌        | 44/293 [01:57<11:03,  2.67s/ Batches]
# Inferencing Samples:  15%|█▌        | 45/293 [01:59<11:00,  2.67s/ Batches]
# Inferencing Samples:  16%|█▌        | 46/293 [02:02<10:58,  2.67s/ Batches]
# Inferencing Samples:  16%|█▌        | 47/293 [02:05<10:55,  2.67s/ Batches]
# Inferencing Samples:  16%|█▋        | 48/293 [02:07<10:53,  2.67s/ Batches]
# Inferencing Samples:  17%|█▋        | 49/293 [02:10<10:51,  2.67s/ Batches]
# Inferencing Samples:  17%|█▋        | 50/293 [02:13<10:48,  2.67s/ Batches]
# Inferencing Samples:  17%|█▋        | 51/293 [02:15<10:45,  2.67s/ Batches]
# Inferencing Samples:  18%|█▊        | 52/293 [02:18<10:42,  2.67s/ Batches]
# Inferencing Samples:  18%|█▊        | 53/293 [02:21<10:39,  2.67s/ Batches]
# Inferencing Samples:  18%|█▊        | 54/293 [02:23<10:37,  2.67s/ Batches]
# Inferencing Samples:  19%|█▉        | 55/293 [02:26<10:34,  2.67s/ Batches]
# Inferencing Samples:  19%|█▉        | 56/293 [02:29<10:32,  2.67s/ Batches]
# Inferencing Samples:  19%|█▉        | 57/293 [02:31<10:29,  2.67s/ Batches]
# Inferencing Samples:  20%|█▉        | 58/293 [02:34<10:26,  2.67s/ Batches]
# Inferencing Samples:  20%|██        | 59/293 [02:37<10:23,  2.67s/ Batches]
# Inferencing Samples:  20%|██        | 60/293 [02:39<10:20,  2.66s/ Batches]
# Inferencing Samples:  21%|██        | 61/293 [02:42<10:18,  2.67s/ Batches]
# Inferencing Samples:  21%|██        | 62/293 [02:45<10:15,  2.67s/ Batches]
# Inferencing Samples:  22%|██▏       | 63/293 [02:47<10:13,  2.67s/ Batches]
# Inferencing Samples:  22%|██▏       | 64/293 [02:50<10:11,  2.67s/ Batches]
# Inferencing Samples:  22%|██▏       | 65/293 [02:53<10:07,  2.67s/ Batches]
# Inferencing Samples:  23%|██▎       | 66/293 [02:55<10:05,  2.67s/ Batches]
# Inferencing Samples:  23%|██▎       | 67/293 [02:58<10:02,  2.67s/ Batches]
# Inferencing Samples:  23%|██▎       | 68/293 [03:01<09:59,  2.67s/ Batches]
# Inferencing Samples:  24%|██▎       | 69/293 [03:03<09:57,  2.67s/ Batches]
# Inferencing Samples:  24%|██▍       | 70/293 [03:06<09:54,  2.67s/ Batches]
# Inferencing Samples:  24%|██▍       | 71/293 [03:11<09:59,  2.70s/ Batches]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-aa511c4f78fd> in <module>()
#       1
# ----> 2 reg_document_store.update_embeddings(reg_retriever)
#       3
#       4 legal_document_store.update_embeddings(legal_retriever)
#       5
#
# /usr/local/lib/python3.7/dist-packages/haystack/document_stores/elasticsearch.py in update_embeddings(self, retriever, index, filters, update_existing_embeddings, batch_size)
#    1029             for result_batch in get_batches_from_generator(result, batch_size):
#    1030                 document_batch = [self._convert_es_hit_to_document(hit, return_embedding=False) for hit in result_batch]
# -> 1031                 embeddings = retriever.embed_documents(document_batch)  # type: ignore
#    1032                 assert len(document_batch) == len(embeddings)
#    1033
#
# /usr/local/lib/python3.7/dist-packages/haystack/nodes/retriever/dense.py in embed_documents(self, docs)
#    1069         :return: Embeddings, one per input document
#    1070         """
# -> 1071         return self.embedding_encoder.embed_documents(docs)
#
# /usr/local/lib/python3.7/dist-packages/haystack/nodes/retriever/_embedding_encoder.py in embed_documents(self, docs)
#      82     def embed_documents(self, docs: List[Document]) -> List[np.ndarray]:
#      83         passages = [d.content for d in docs] # type: ignore
# ---> 84         return self.embed(passages)
#      85
#      86
#
# /usr/local/lib/python3.7/dist-packages/haystack/nodes/retriever/_embedding_encoder.py in embed(self, texts)
#      73         # TODO: FARM's `sample_to_features_text` need to fix following warning -
#      74         # tokenization_utils.py:460: FutureWarning: `is_pretokenized` is deprecated and will be removed in a future version, use `is_split_into_words` instead.
# ---> 75         emb = self.embedding_model.inference_from_dicts(dicts=[{"text": t} for t in texts])
#      76         emb = [(r["vec"]) for r in emb]
#      77         return emb
#
# /usr/local/lib/python3.7/dist-packages/haystack/modeling/infer.py in inference_from_dicts(self, dicts, return_json, multiprocessing_chunksize)
#     319
#     320         if self.process_pool is None:  # multiprocessing disabled (helpful for debugging or using in web frameworks)
# --> 321             predictions: Any = self._inference_without_multiprocessing(dicts, return_json, aggregate_preds)
#     322             return predictions
#     323         else:  # use multiprocessing for inference
#
# /usr/local/lib/python3.7/dist-packages/haystack/modeling/infer.py in _inference_without_multiprocessing(self, dicts, return_json, aggregate_preds)
#     360             preds_all = self._get_predictions_and_aggregate(dataset, tensor_names, baskets)
#     361         else:
# --> 362             preds_all = self._get_predictions(dataset, tensor_names, baskets)
#     363
#     364         if return_json:
#
# /usr/local/lib/python3.7/dist-packages/haystack/modeling/infer.py in _get_predictions(self, dataset, tensor_names, baskets)
#     457                     tokenizer=self.processor.tokenizer,
#     458                     return_class_probs=self.return_class_probs,
# --> 459                     **batch)
#     460                 preds_all += preds
#     461         return preds_all
#
# /usr/local/lib/python3.7/dist-packages/haystack/modeling/model/adaptive_model.py in formatted_preds(self, logits, **kwargs)
#      81         if n_heads == 0:
#      82             # just return LM output (e.g. useful for extracting embeddings at inference time)
# ---> 83             preds_final = self.language_model.formatted_preds(logits=logits, **kwargs)
#      84
#      85         elif n_heads == 1:
#
# /usr/local/lib/python3.7/dist-packages/haystack/modeling/model/language_model.py in formatted_preds(self, logits, samples, ignore_first_token, padding_mask, input_ids, **kwargs)
#     395             vecs = sequence_output.cpu().numpy()
#     396         elif self.extraction_strategy == "reduce_mean":
# --> 397             vecs = self._pool_tokens(sequence_output, padding_mask, self.extraction_strategy, ignore_first_token=ignore_first_token)
#     398         elif self.extraction_strategy == "reduce_max":
#     399             vecs = self._pool_tokens(sequence_output, padding_mask, self.extraction_strategy, ignore_first_token=ignore_first_token)
#
# /usr/local/lib/python3.7/dist-packages/haystack/modeling/model/language_model.py in _pool_tokens(self, sequence_output, padding_mask, strategy, ignore_first_token)
#     412
#     413     def _pool_tokens(self, sequence_output, padding_mask, strategy, ignore_first_token):
# --> 414         token_vecs = sequence_output.cpu().numpy()
#     415         # we only take the aggregated value of non-padding tokens
#     416         padding_mask = padding_mask.cpu().numpy()
#
# KeyboardInterrupt:

# %%
import pickle

# from haystack.utils import launch_milvus
# from haystack.document_stores import MilvusDocumentStore

# launch_milvus()
# reg_document_store = MilvusDocumentStore()

from haystack.document_stores import FAISSDocumentStore

reg_document_store = FAISSDocumentStore(faiss_index_factory_str="Flat")
legal_document_store = FAISSDocumentStore(faiss_index_factory_str="Flat")
misc_document_store = FAISSDocumentStore(faiss_index_factory_str="Flat")

with open("/content/drive/MyDrive/CollabData/RegulationElasticDict.pkl","rb") as f:
  dicts = pickle.load(f)

reg_document_store.write_documents(dicts)

with open("/content/drive/MyDrive/CollabData/CaseElasticDict.pkl","rb") as f:
  dicts = pickle.load(f)

legal_document_store.write_documents(dicts)

with open("/content/drive/MyDrive/CollabData/MiscElasticDict.pkl","rb") as f:
  dicts = pickle.load(f)

misc_document_store.write_documents(dicts)
# Out:
# ---------------------------------------------------------------------------
# ContextualVersionConflict                 Traceback (most recent call last)
# <ipython-input-6-79050e212193> in <module>()
#       7 # reg_document_store = MilvusDocumentStore()
#       8
# ----> 9 from haystack.document_stores import FAISSDocumentStore
#      10
#      11 reg_document_store = FAISSDocumentStore(faiss_index_factory_str="Flat")
#
# /usr/local/lib/python3.7/dist-packages/haystack/__init__.py in <module>()
#       5 logging.getLogger("haystack").setLevel(logging.INFO)
#       6
# ----> 7 from haystack import pipelines
#       8 from haystack.schema import Document, Answer, Label, MultiLabel, Span
#       9 from haystack.nodes import BaseComponent
#
# /usr/local/lib/python3.7/dist-packages/haystack/pipelines/__init__.py in <module>()
# ----> 1 from haystack.pipelines.base import Pipeline, RootNode, RayPipeline
#       2 from haystack.pipelines.standard_pipelines import (
#       3     BaseStandardPipeline,
#       4     DocumentSearchPipeline,
#       5     QuestionGenerationPipeline,
#
# /usr/local/lib/python3.7/dist-packages/haystack/pipelines/base.py in <module>()
#      14 from networkx import DiGraph
#      15 from networkx.drawing.nx_agraph import to_agraph
# ---> 16 from haystack.nodes.evaluator.evaluator import calculate_em_str_multi, calculate_f1_str_multi, semantic_answer_similarity
#      17
#      18 try:
#
# /usr/local/lib/python3.7/dist-packages/haystack/nodes/__init__.py in <module>()
#       1 from haystack.nodes.base import BaseComponent
# ----> 2 from haystack.nodes.answer_generator import BaseGenerator, RAGenerator, Seq2SeqGenerator
#       3 from haystack.nodes.connector import Crawler
#       4 from haystack.nodes.document_classifier import BaseDocumentClassifier, TransformersDocumentClassifier
#       5 from haystack.nodes.evaluator import EvalDocuments, EvalAnswers
#
# /usr/local/lib/python3.7/dist-packages/haystack/nodes/answer_generator/__init__.py in <module>()
#       1 from haystack.nodes.answer_generator.base import BaseGenerator
# ----> 2 from haystack.nodes.answer_generator.transformers import RAGenerator, Seq2SeqGenerator
#
# /usr/local/lib/python3.7/dist-packages/haystack/nodes/answer_generator/transformers.py in <module>()
#      12 from haystack.schema import Answer, Document
#      13 from haystack.nodes.answer_generator.base import BaseGenerator
# ---> 14 from haystack.nodes.retriever.dense import DensePassageRetriever
#      15
#      16
#
# /usr/local/lib/python3.7/dist-packages/haystack/nodes/retriever/__init__.py in <module>()
#       1 from haystack.nodes.retriever.base import BaseRetriever
# ----> 2 from haystack.nodes.retriever.dense import DensePassageRetriever, EmbeddingRetriever, TableTextRetriever
#       3 from haystack.nodes.retriever.sparse import ElasticsearchRetriever, ElasticsearchFilterOnlyRetriever, TfidfRetriever
#       4 from haystack.nodes.retriever.text2sparql import Text2SparqlRetriever
#
# /usr/local/lib/python3.7/dist-packages/haystack/nodes/retriever/dense.py in <module>()
#      11
#      12 from haystack.schema import Document
# ---> 13 from haystack.document_stores import BaseDocumentStore
#      14 from haystack.nodes.retriever.base import BaseRetriever
#      15 from haystack.nodes.retriever._embedding_encoder import _EMBEDDING_ENCODERS
#
# /usr/local/lib/python3.7/dist-packages/haystack/document_stores/__init__.py in <module>()
#       9     from haystack.document_stores.milvus2x import Milvus2DocumentStore as MilvusDocumentStore
#      10 else:
# ---> 11     from haystack.document_stores.milvus import MilvusDocumentStore  # type: ignore
#      12
#      13 from haystack.document_stores.sql import SQLDocumentStore
#
# /usr/local/lib/python3.7/dist-packages/haystack/document_stores/milvus.py in <module>()
#       9 from scipy.special import expit
#      10
# ---> 11 from milvus import IndexType, MetricType, Milvus, Status
#      12
#      13 from haystack.schema import Document
#
# /usr/local/lib/python3.7/dist-packages/milvus/__init__.py in <module>()
#       1 # -*- coding: utf-8 -*-
#       2
# ----> 3 from .client.stub import Milvus
#       4 from .client.prepare import Prepare
#       5 from .client.types import IndexType, MetricType, Status
#
# /usr/local/lib/python3.7/dist-packages/milvus/client/__init__.py in <module>()
#       5
#       6 try:
# ----> 7     __version__ = get_distribution('pymilvus').version
#       8 except DistributionNotFound:
#       9     # package is not installed
#
# /usr/local/lib/python3.7/dist-packages/pkg_resources/__init__.py in get_distribution(dist)
#     464         dist = Requirement.parse(dist)
#     465     if isinstance(dist, Requirement):
# --> 466         dist = get_provider(dist)
#     467     if not isinstance(dist, Distribution):
#     468         raise TypeError("Expected string, Requirement, or Distribution", dist)
#
# /usr/local/lib/python3.7/dist-packages/pkg_resources/__init__.py in get_provider(moduleOrReq)
#     340     """Return an IResourceProvider for the named module or requirement"""
#     341     if isinstance(moduleOrReq, Requirement):
# --> 342         return working_set.find(moduleOrReq) or require(str(moduleOrReq))[0]
#     343     try:
#     344         module = sys.modules[moduleOrReq]
#
# /usr/local/lib/python3.7/dist-packages/pkg_resources/__init__.py in require(self, *requirements)
#     884         included, even if they were already activated in this working set.
#     885         """
# --> 886         needed = self.resolve(parse_requirements(requirements))
#     887
#     888         for dist in needed:
#
# /usr/local/lib/python3.7/dist-packages/pkg_resources/__init__.py in resolve(self, requirements, env, installer, replace_conflicting, extras)
#     775                 # Oops, the "best" so far conflicts with a dependency
#     776                 dependent_req = required_by[req]
# --> 777                 raise VersionConflict(dist, req).with_context(dependent_req)
#     778
#     779             # push the new requirements onto the stack
#
# ContextualVersionConflict: (grpcio 1.42.0 (/usr/local/lib/python3.7/dist-packages), Requirement.parse('grpcio<1.38.0,>=1.22.0'), {'pymilvus'})

# %%
from haystack.nodes import DensePassageRetriever
reg_retriever = DensePassageRetriever(document_store=reg_document_store,
                                  query_embedding_model="facebook/dpr-question_encoder-single-nq-base",
                                  passage_embedding_model="facebook/dpr-ctx_encoder-single-nq-base",
                                  max_seq_len_query=128,
                                  max_seq_len_passage=512,
                                  batch_size=16,
                                  use_gpu=True,
                                  embed_title=True,
                                  use_fast_tokenizers=True)
# Important: 
# Now that after we have the DPR initialized, we need to call update_embeddings() to iterate over all
# previously indexed documents and update their embedding representation. 
# While this can be a time consuming operation (depending on corpus size), it only needs to be done once. 
# At query time, we only need to embed the query and compare it the existing doc embeddings which is very fast.
reg_document_store.update_embeddings(reg_retriever)

legal_retriever = DensePassageRetriever(document_store=legal_document_store,
                                  query_embedding_model="facebook/dpr-question_encoder-single-nq-base",
                                  passage_embedding_model="facebook/dpr-ctx_encoder-single-nq-base",
                                  max_seq_len_query=128,
                                  max_seq_len_passage=512,
                                  batch_size=16,
                                  use_gpu=True,
                                  embed_title=True,
                                  use_fast_tokenizers=True)

legal_document_store.update_embeddings(legal_retriever)


misc_retriever = DensePassageRetriever(document_store=misc_document_store,
                                  query_embedding_model="facebook/dpr-question_encoder-single-nq-base",
                                  passage_embedding_model="facebook/dpr-ctx_encoder-single-nq-base",
                                  max_seq_len_query=128,
                                  max_seq_len_passage=512,
                                  batch_size=16,
                                  use_gpu=True,
                                  embed_title=True,
                                  use_fast_tokenizers=True)

misc_document_store.update_embeddings(misc_retriever)

# %% [markdown]
# ### DataPrep

# %%
import pandas as pd

df = pd.read_csv("/content/drive/MyDrive/CollabData/QnA_Latest.csv")
df.index.name="id"
df
# Out:
#                                                                             question  ... Annotator
# id                                                                                    ...
# 0     Does an innocent recipient of UPSI have any defence under the PIT regulations?  ...       NaN
# 1    Will a promoter group entity require a pre-clearance from a related company ...  ...       NaN
# 2    Is inter-se off-market transfer of shares between insiders within a period o...  ...       NaN
# 3                     Can an AIF invest its unutilized funds in liquid mutual funds?  ...       NaN
# 4       What are the penal consequences of not furnishing information asked by SEBI?  ...       NaN
# ..                                                                               ...  ...       ...
# 103                                                                   What is InvIT?  ...       Raj
# 104                     What does the Section 77A of the Companies Act, 1956 entail?  ...       Raj
# 105                     What does the Section 77A(4) of the Companies Act, 1956 say?  ...       Raj
# 106                     What does the Section 77A(2) of the Companies Act, 1956 say?  ...       Raj
# 107  What does the Section 19(1)(e) of SEBI(Buy back of Securities) regulations, ...  ...       Raj
#
# [108 rows x 7 columns]

# %%
def start_index(span,context):
  return context.find(span)
      
df["Start index"] = df.apply(lambda x: start_index(x["Answer Span"],x["context"]),axis=1)
df[["Answer Span","context","Start index"]]
# Out:
#                                                                          Answer Span  ... Start index
# id                                                                                    ...
# 0    insider may prove his innocence by demonstrating the inclusive list of circu...  ...         844
# 1    only by "Designated persons" if the value of the proposed trades is above su...  ...         741
# 2    promoters have the option to convert warrants any time within 18 months from...  ...          30
# 3    may invest investment income or investment proceeds arising from sale or tra...  ...         278
# 4                   attract the penalty prescribed under section 15A of the SEBI Act  ...         248
# ..                                                                               ...  ...         ...
# 103  vehicles allowing for adding of projects in future in\nthe same vehicle so t...  ...          26
# 104       contains the basic framework for\ncompanies to buy back its own securities  ...          39
# 105                 every buy back shall\nbe completed within a period of 12 months.  ...          57
# 106                  prohibits only back to back\nbuy backs through board resolution  ...          41
# 107  The company shall ensure that the promoter or the person shall not deal in\n...  ...          84
#
# [108 rows x 3 columns]

# %%
df[df["Start index"]==-1]
# Out:
#                                                                 question  ... Annotator
# id                                                                        ...
# 80       What is the capital adequacy requirement for a Merchant banker?  ...    Vrinda
# 86                                         What is corporate governance?  ...       Raj
# 87                                                 What is Crowdfunding?  ...       Raj
# 88                                                 What is a green bond?  ...       Raj
# 95  How many stock exchanges in India are corporatised and demutualised?  ...       Raj
#
# [5 rows x 7 columns]

# %%
df = df[df["Start index"]!=-1]
df = df.reset_index()
df
# Out:
#       id  ... Annotator
# 0      0  ...       NaN
# 1      1  ...       NaN
# 2      2  ...       NaN
# 3      3  ...       NaN
# 4      4  ...       NaN
# ..   ...  ...       ...
# 98   103  ...       Raj
# 99   104  ...       Raj
# 100  105  ...       Raj
# 101  106  ...       Raj
# 102  107  ...       Raj
#
# [103 rows x 8 columns]

# %%
def preprocess(t,s):
  return {"answer_start":[s],"text":[t]}

df["answers"] = df.apply(lambda x: preprocess(x["Answer Span"],x["Start index"]),axis=1)
df
# Out:
#       id  ...                                                                          answers
# 0      0  ...  {'answer_start': [844], 'text': ['insider may prove his innocence by demonst...
# 1      1  ...  {'answer_start': [741], 'text': ['only by "Designated persons" if the value ...
# 2      2  ...  {'answer_start': [30], 'text': ['promoters have the option to convert warran...
# 3      3  ...  {'answer_start': [278], 'text': ['may invest investment income or investment...
# 4      4  ...  {'answer_start': [248], 'text': ['attract the penalty prescribed under secti...
# ..   ...  ...                                                                              ...
# 98   103  ...  {'answer_start': [26], 'text': ['vehicles allowing for adding of projects in...
# 99   104  ...  {'answer_start': [39], 'text': ['contains the basic framework for
# companies ...
# 100  105  ...  {'answer_start': [57], 'text': ['every buy back shall
# be completed within a ...
# 101  106  ...  {'answer_start': [41], 'text': ['prohibits only back to back
# buy backs throu...
# 102  107  ...  {'answer_start': [84], 'text': ['The company shall ensure that the promoter ...
#
# [103 rows x 9 columns]

# %%
df=df.drop(["Start index"],axis=1)
df
# Out:
#       id  ...                                                                          answers
# 0      0  ...  {'answer_start': [844], 'text': ['insider may prove his innocence by demonst...
# 1      1  ...  {'answer_start': [741], 'text': ['only by "Designated persons" if the value ...
# 2      2  ...  {'answer_start': [30], 'text': ['promoters have the option to convert warran...
# 3      3  ...  {'answer_start': [278], 'text': ['may invest investment income or investment...
# 4      4  ...  {'answer_start': [248], 'text': ['attract the penalty prescribed under secti...
# ..   ...  ...                                                                              ...
# 98   103  ...  {'answer_start': [26], 'text': ['vehicles allowing for adding of projects in...
# 99   104  ...  {'answer_start': [39], 'text': ['contains the basic framework for
# companies ...
# 100  105  ...  {'answer_start': [57], 'text': ['every buy back shall
# be completed within a ...
# 101  106  ...  {'answer_start': [41], 'text': ['prohibits only back to back
# buy backs throu...
# 102  107  ...  {'answer_start': [84], 'text': ['The company shall ensure that the promoter ...
#
# [103 rows x 8 columns]

# %%
import pickle
docs = ["Issue and Listing of Non Convertible Redeemable Preference Shares", "Investment Advisers", "Depositories and Participants", "Mutual Funds", "Employees Service", "Substantial Acquisition of Shares and Takeovers", "Appointment of Administrator and Procedure for Refunding to the Investors", "Prohibition of Fraudulent and Unfair Trade Practices relating to Securities Market", "Know Your Client Regulations", "Prohibition of Insider Trading", "Merchant Bankers", "Issue and Listing  of Securities Debt Instruments and Security Receipts", "Delisting of Equity Shares","Issue of Capital And Disclosure Requirements2", "Foreign Venture Capital Investor", "Procedure for Board Meetings", "Custodian", "Ombudsman", "Investor Protection and Education Fund", "Foreign Portfolio Investors", "Issue of Sweat Equity", "Collective Investment Scheme", "Portfolio Managers", "Research Analysts", "Procedure for Search and Seizure", "Issue of Capital And Disclosure Requirements", "Share Based Employee Benefits", "Debenture Trustees", "Alternative Investment Funds", "Stock Exchanges and Clearing Corporations", "Self Regulatory Organisations", "Settlement Proceedings", "Issues and Listing of Muncipal Debt Securities", "Buy Back Of Securities2","Issue and Listing of Debt Securities", "Infrastructure Investment Trusts", "Stock Brokers", "Listing Obligations and Disclosure Requirements", "Registrars to an Issue and Share Transfer Agents", "Real Estate Investment Trusts", "Intermediaries", "Certification of Associated Persons in the Securities Markets", "Credit Rating Agencies", "Regulatory Fee on Stock Exchanges", "Underwriters", "Buy Back Of Securities", "Bankers to an Issue", "Central Database of Market Participants"]
#Legal Case files
with open('/content/drive/MyDrive/CollabData/case_filenames.pkl','rb') as f:
    lfile = pickle.load(f)

# %%
from tqdm import tqdm

def fileType(name):
    if name+".txt" in lfile:
        return "legal case"
    if name in docs:
        return "regulations"
    return "misc"

# %%
df["doc_type"]=df["Document"].apply(fileType)
len(df[df["doc_type"]=="regulations"]),len(df[df["doc_type"]=="misc"]),len(df[df["doc_type"]=="legal case"])
# Out:
# (39, 30, 34)

# %% [markdown]
# testing

# %%
DATA = "data/"
regdf = df[df["doc_type"]=="regulations"]
docs = ["Issue and Listing of Non Convertible Redeemable Preference Shares", "Investment Advisers", "Depositories and Participants", "Mutual Funds", "Employees Service", "Substantial Acquisition of Shares and Takeovers", "Appointment of Administrator and Procedure for Refunding to the Investors", "Prohibition of Fraudulent and Unfair Trade Practices relating to Securities Market", "Know Your Client Regulations", "Prohibition of Insider Trading", "Merchant Bankers", "Issue and Listing  of Securities Debt Instruments and Security Receipts", "Delisting of Equity Shares","Issue of Capital And Disclosure Requirements2", "Foreign Venture Capital Investor", "Procedure for Board Meetings", "Custodian", "Ombudsman", "Investor Protection and Education Fund", "Foreign Portfolio Investors", "Issue of Sweat Equity", "Collective Investment Scheme", "Portfolio Managers", "Research Analysts", "Procedure for Search and Seizure", "Issue of Capital And Disclosure Requirements", "Share Based Employee Benefits", "Debenture Trustees", "Alternative Investment Funds", "Stock Exchanges and Clearing Corporations", "Self Regulatory Organisations", "Settlement Proceedings", "Issues and Listing of Muncipal Debt Securities", "Buy Back Of Securities2","Issue and Listing of Debt Securities", "Infrastructure Investment Trusts", "Stock Brokers", "Listing Obligations and Disclosure Requirements", "Registrars to an Issue and Share Transfer Agents", "Real Estate Investment Trusts", "Intermediaries", "Certification of Associated Persons in the Securities Markets", "Credit Rating Agencies", "Regulatory Fee on Stock Exchanges", "Underwriters", "Buy Back Of Securities", "Bankers to an Issue", "Central Database of Market Participants"]
with open(DATA + 'cleanedregulations48.pkl','rb') as f:
    docregs = pickle.load(f)    

regMap = dict()
for key,val in zip(docs,docregs):
  regMap[key]=val

missing=list()
count=0
for i, r in regdf.iterrows():
  flag = False
  for ele in regMap[r["Document"]]:
    
    if " ".join(r["Answer Span"].split()) in " ".join(ele.split()):
      flag=True
      break
  if not flag:
    missing.append(r["id"])
    count+=1
# count

# %%
regdf[regdf["id"].isin(missing)]
# Out:
#     id  ...     doc_type
# 11  11  ...  regulations
# 15  15  ...  regulations
# 30  30  ...  regulations
# 32  32  ...  regulations
# 59  59  ...  regulations
# 66  66  ...  regulations
# 67  67  ...  regulations
# 74  74  ...  regulations
# 75  75  ...  regulations
# 76  76  ...  regulations
# 77  77  ...  regulations
#
# [11 rows x 9 columns]

# %%
regMap["Listing Obligations and Disclosure Requirements"]

# answer spans present in Definitions section of regulations anol will not be in the pickles
# "Ombudsman" question in id 32 is an example where the regulation, due to the pdf parser, has the text not present as it is in the pdf
# ok the definitions part is a good majority of the missing files causes

# %%
set(regdf["Document"].tolist())

# %%
miscdf = df[df["doc_type"]=="misc"]


with open('data/misc_filenames_testing.pkl','rb') as filer:
    lcfiles = pickle.load(filer)

with open( 'data/misc_origreg_testing.pkl','rb') as filer:
    origreg = pickle.load(filer)

miscMap = dict()
for key,val in zip(lcfiles,origreg):
  if key not in miscMap.keys():
    miscMap[key]=list()
  miscMap[key].append(val)

missingmisc = list()
count=0
for i, x in miscdf.iterrows():
  flag = False
  for ele in miscMap[x["Document"]]:
    for subreg in ele:
      if x["Answer Span"] in subreg:
        flag=True
        break
  if not flag:
    missingmisc.append(x["id"])
    count+=1
count
# Out:
# 30

# %%
# miscMap["9f6295e22d780cad4195bcbf8cba3d4b"]
miscdf[miscdf["id"].isin(missingmisc)]
# for x in miscMap["9f6295e22d780cad4195bcbf8cba3d4b"]:
#   print(x)
#   print("\n")
# Out:
#       id  ... doc_type
# 1      1  ...     misc
# 2      2  ...     misc
# 3      3  ...     misc
# 7      7  ...     misc
# 8      8  ...     misc
# 20    20  ...     misc
# 21    21  ...     misc
# 22    22  ...     misc
# 23    23  ...     misc
# 24    24  ...     misc
# 83    84  ...     misc
# 84    85  ...     misc
# 85    89  ...     misc
# 86    90  ...     misc
# 87    91  ...     misc
# 88    92  ...     misc
# 89    93  ...     misc
# 90    94  ...     misc
# 91    96  ...     misc
# 92    97  ...     misc
# 93    98  ...     misc
# 94    99  ...     misc
# 95   100  ...     misc
# 96   101  ...     misc
# 97   102  ...     misc
# 98   103  ...     misc
# 99   104  ...     misc
# 100  105  ...     misc
# 101  106  ...     misc
# 102  107  ...     misc
#
# [30 rows x 9 columns]

# %%
miscMap["1387543144855"]
# Out:
# ['C\x00o\x00n\x00s\x00u\x00l\x00t\x00a\x00t\x00i\x00o\x00n\x00 \x00p\x00a\x00p\x00e\x00r\x00 \x00o\x00n\x00 \x00I\x00n\x00f\x00r\x00a\x00s\x00t\x00r\x00u\x00c\x00t\x00u\x00r\x00e\x00 \x00I\x00n\x00v\x00e\x00s\x00t\x00m\x00e\x00n\x00t\x00 \x00T\x00r\x00u\x00s\x00t\x00s\x00\x00\x001\x00.\x00 \x00I\x00n\x00f\x00r\x00a\x00s\x00t\x00r\x00u\x00c\x00t\x00u\x00r\x00e\x00 \x00i\x00s\x00 \x00t\x00h\x00e\x00 \x00c\x00o\x00r\x00n\x00e\x00r\x00s\x00t\x00o\x00n\x00e\x00 \x00o\x00f\x00 \x00d\x00e\x00v\x00e\x00l\x00o\x00p\x00m\x00e\x00n\x00t\x00 \
# %%
legaldf = df[df["doc_type"]=="legal case"]

with open('data/legal_filenames_testing.pkl','rb') as filer:
    lcfiles = pickle.load(filer)

with open( 'data/legal_origreg_testing.pkl','rb') as filer:
    origreg = pickle.load(filer)

legalMap = dict()
for key,val in zip(lcfiles,origreg):
  if key not in legalMap.keys():
    legalMap[key]=list()
  legalMap[key].append(val)


count=0
legalmissing = list()
for i, x in legaldf.iterrows():
  flag = False
  for ele in legalMap[x["Document"]+".pdf"]:
    if flag:
      break

    for subreg in ele:
      if x["Answer Span"] in subreg:
        flag=True
        break


  if not flag:
    legalmissing.append(x["id"])
    count+=1
count
# Out:
# 34

# %%
legaldf[legaldf["id"].isin(legalmissing)]
# Out:
#     id  ...    doc_type
# 0    0  ...  legal case
# 4    4  ...  legal case
# 5    5  ...  legal case
# 6    6  ...  legal case
# 9    9  ...  legal case
# 25  25  ...  legal case
# 26  26  ...  legal case
# 27  27  ...  legal case
# 28  28  ...  legal case
# 34  34  ...  legal case
# 35  35  ...  legal case
# 36  36  ...  legal case
# 37  37  ...  legal case
# 38  38  ...  legal case
# 39  39  ...  legal case
# 40  40  ...  legal case
# 41  41  ...  legal case
# 42  42  ...  legal case
# 43  43  ...  legal case
# 44  44  ...  legal case
# 45  45  ...  legal case
# 46  46  ...  legal case
# 47  47  ...  legal case
# 48  48  ...  legal case
# 49  49  ...  legal case
# 50  50  ...  legal case
# 51  51  ...  legal case
# 52  52  ...  legal case
# 53  53  ...  legal case
# 54  54  ...  legal case
# 55  55  ...  legal case
# 56  56  ...  legal case
# 57  57  ...  legal case
# 58  58  ...  legal case
#
# [34 rows x 9 columns]

# %%
for t in legalMap["1312182027229.pdf"]:
  print(t)
  print()
# Out:
# - OrderGennexLaboratories[1].doc Adjudication Order In Respect of Gennex Laboratories Ltd and its Directors July 29, 2011 In The Matter of Gennex Laboratories Ltd BEFORE THE ADJUDICATING OFFICER SECURITIES AND EXCHANGE BOARD OF INDIA [ADJUDICATION ORDER No PKB AO- 42 2011] UNDER SECTION 15-I OF SECURITIES AND EXCHANGE BOARD OF INDIA ACT, 1992 READ WITH RULE 5 OF SEBI (PROCEDURE FOR HOLDING INQUIRY AND IMPOSING PENALTIES BY ADJUDICATING OFFICER) RULES, 1995 In Respect Of Gennex Laboratories Ltd And its directors: Vinod Baid U.C. Bhandari Y. Ravinder Reddy Kishore Jhunjhunwala BRIEF FACTS OF THE CASE 1. Investigation into the affairs relating to buying and selling or dealing in the shares of Gennex Laboratories Limited (hereinafter referred to as ‘Noticee -1’ or ‘GLL’ or ‘the company’) was made to ascertain whether any provision of the SEBI Act, 1992 and various rules and regulations made there under have been violated. The main focus of the investigation was to ascertain whether there was any violation of the provisions of SEBI (Prohibition of Fraudulent and Unfair Trade Practices relating to Securities Market) Regulations, 2003 and SEBI (Substantial Acquisition of Shares and Takeovers) Regulations, 1997 during the period of April 30, 2007 to November 18, 2008 (hereinafter referred to as the 
However, such non-cooperation with investigative authorities leads to delay in the unraveling of unfair market practices, which results in the erosion of investor confidence in the market. 28. In the foregoing paragraphs it is No established that Noticee-1, Gennex Laboratories Ltd., failed to provide necessary information to the Investigating Authority of SEBI in response to the summons issued in terms of Section 11(3) of the SEBI Act, 1992. The said information was very relevant and important in the whole investigation process. It is noted that the company had made certain announcements which did No materialise but had lead to a rise in the price of its shares. During this period of price-rise, it was observed that promoter entities had offloaded their shares in the market. By No providing this crucial information which could have unraveled serious manipulative or fraudulent practices on the part of the company or entities related to it, Noticee-1 seriously crippled the investigative process. In this regard, I refer to the observation of the Hon’ble Securities Appellate Tribunal in Appeal No 184 of 2010 (Mr. Jalaj Batra vs. SEBI, decided on 06-12-2010); wherein it was held that - “…….Having regard to the circumstances of this case, we are more than satisfied that the summons had in fact been received by the appellant and that he failed to respond to the same. We have observed time and again that it is of utmost importance that market players like the appellant should fully cooperate with the investigations that are carried out by the Board, the watchdog of the securities market. If market players and intermediaries avoid appearing before the investigating officer or furnish the necessary information sought from them, the Board as a market regulator will No be able to carry out its statutory functions and duties of protecting the integrity of the securities market and the investigations would be grossly hampered. No co-operation with the market regulator has to be viewed seriously. We do No know what else would have come to light if the appellant had appeared before the investigating officer or if he had furnished the requisite information that was sought from him.............” Thereby, it is established beyond doubt that Noticee-1 tried to elude the Investigating Authority, which hampered the investigation process. Considering the facts and circumstances of the case and the violation committed by Noitcee-1, I am of the view
#
# that imposing a penalty of Rs. 10, 00,000 - (Rs. Adjudication Order In Respect of Gennex Laboratories Ltd and its Directors July 29, 2011 In The Matter of Gennex Laboratories Ltd Ten Lakhs only) on Gennex Laboratories Ltd would be commensurate with the violation of Section 11C (2) and 11C (3) read with Section 11 C (6) of the SEBI Act by Noticee-1. ORDER: 29. Considering the facts and circumstances of the case, in terms of the provision of Section 15A (a) of SEBI Act and Rule 5(1) of the Rules, I hereby impose a penalty of Rs. 10, 00,000 - (Rupees Ten Lakhs only) on Gennex Laboratories Ltd for No compliance of summons issued by Investigation Authority. 30. The penalty shall be paid by way of demand draft drawn in favour of “SEBI – Penalties Remittable to Government of India” payable at Mumbai within 45 days of receipt of this order. The said demand draft shall be forwarded to Shri Ashish Kumar, DGM, Investigation Department, Securities and Exchange Board of India, Plot No C4-A, ‘G’ Block, Bandra Kurla Complex, Bandra (E), Mumbai – 400 051. 31. In terms of the provisions of Rule 6 of the SEBI (Procedure for Holding Inquiry and Imposing Penalties by Adjudicating Officer) Rules 1995, copies of this order are sent to the noticee and also to Securities and Exchange Board of India. Date: July 29, 2011 P. K. Bindlish Place: Mumbai Adjudicating Officer

# %% [markdown]
# ### Evaluating retrievers

# %%
# !unzip /content/drive/MyDrive/CollabData/pipeline.zip
# Out:
# Archive:  /content/drive/MyDrive/CollabData/pipeline.zip
#    creating: data/
#   inflating: data/misc_DF_new.json
#   inflating: data/legal_filenames_testing.pkl
#   inflating: data/informal_queries.pkl
#   inflating: data/finaltrain.pkl
#   inflating: data/misc_tf_idf.pkl
#   inflating: data/misc_total_vocab_new.pkl
#   inflating: data/case_origreg.pkl
#  extracting: data/misc_tf_idf.json
#    creating: data/QnA_version1/
#   inflating: data/QnA_version1/case_origreg.pkl
#   inflating: data/QnA_version1/misc_origreg.pkl
#   inflating: data/cleanedregtopics48.pkl
#   inflating: data/misc_origreg.pkl
#   inflating: data/trainquery.pkl
#   inflating: data/case_total_vocab_new.pkl
#   inflating: data/case_queries.pkl
#   inflating: data/misc_filenames_testing.pkl
#   inflating: data/misc_origreg_new.pkl
#   inflating: data/cleanedregulations48.pkl
#   inflating: data/misc_tf_idf_new.pkl
#   inflating: data/case_origreg_new.pkl
#   inflating: data/informal_sentences.pkl
#   inflating: data/case_sentences.pkl
#   inflating: data/case_tf_idf_new.pkl
#   inflating: data/informal_text.pkl
#   inflating: data/casevocab.pkl
#   inflating: data/misc_origreg_testing.pkl
#   inflating: data/concept_queries.pkl
#   inflating: data/vocabdef.pkl
#   inflating: data/case_DF_new.json
#   inflating: data/case_filenames.pkl
#   inflating: data/misc_total_vocab.pkl
#   inflating: data/mainvocab.pkl
#   inflating: data/miscfiles_mapper.pkl
#   inflating: data/case_DF.json
#   inflating: data/miscvocab.pkl
#   inflating: data/case_total_vocab.pkl
#   inflating: data/legal_origreg_testing.pkl
#   inflating: data/casefiles_mapper.pkl
#   inflating: data/new_cleanedregulations48.pkl
#   inflating: data/README.md
#   inflating: data/tfidf_regs.pkl
#   inflating: data/concept_sentences.pkl
#   inflating: data/glossary.json
#   inflating: data/misc_DF.json
#    creating: data/Definitions/
#   inflating: data/Definitions/Issue and Listing of Non Convertible Redeemable Preference Shares.json
#   inflating: data/Definitions/Merchant Bankers.json
#   inflating: data/Definitions/Listing Obligations and Disclosure Requirements.json
#   inflating: data/Definitions/Portfolio Managers.json
#   inflating: data/Definitions/Ombudsman.json
#   inflating: data/Definitions/Foreign Portfolio Investors.json
#   inflating: data/Definitions/Procedure for Search and Seizure.json
#   inflating: data/Definitions/Depositories and Participants.json
#   inflating: data/Definitions/Procedure for Board Meetings.json
#   inflating: data/Definitions/Know Your Client Regulations.json
#   inflating: data/Definitions/Credit Rating Agencies.json
#   inflating: data/Definitions/Registrars to an Issue and Share Transfer Agents.json
#   inflating: data/Definitions/Investment Advisers.json
#   inflating: data/Definitions/Certification of Associated Persons in the Securities Markets.json
#   inflating: data/Definitions/Alternative Investment Funds.json
#   inflating: data/Definitions/Issue and Listing  of Securities Debt Instruments and Security Receipts.json
#   inflating: data/Definitions/Regulatory Fee on Stock Exchanges.json
#   inflating: data/Definitions/Settlement Proceedings.json
#   inflating: data/Definitions/Substantial Acquisition of Shares and Takeovers.json
#   inflating: data/Definitions/Employees Service.json
#   inflating: data/Definitions/Intermediaries.json
#   inflating: data/Definitions/Custodian.json
#   inflating: data/Definitions/Self Regulatory Organisations.json
#   inflating: data/Definitions/Bankers to an Issue.json
#   inflating: data/Definitions/Stock Exchanges and Clearing Corporations.json
#    creating: data/Definitions/.ipynb_checkpoints/
#   inflating: data/Definitions/Prohibition of Fraudulent and Unfair Trade Practices relating to Securities Market.json
#   inflating: data/Definitions/README.md
#   inflating: data/Definitions/Issue of Capital And Disclosure Requirements.json
#   inflating: data/Definitions/Issues and Listing of Muncipal Debt Securities.json
#   inflating: data/Definitions/Prohibition of Insider Trading.json
#   inflating: data/Definitions/Investor Protection and Education Fund.json
#   inflating: data/Definitions/Stock Brokers.json
#   inflating: data/concept_text.pkl
#   inflating: data/informal_filenames.pkl
#   inflating: data/case_tf_idf.pkl
#   inflating: data/case_text.pkl
#   inflating: data/casefiles_sentences_new.pkl
#   inflating: data/concept_filenames.pkl
#   inflating: data/reg_topics.pkl

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')

from nltk.corpus import stopwords
import spacy
from nltk.metrics import edit_distance
from nltk.corpus import wordnet
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
import os, json
import pickle

DATA = "data/"
nlp = spacy.load('en_core_web_sm')
defdict = {}
path_to_json = DATA + 'Definitions/'
json_files = [pos_json for pos_json in os.listdir(path_to_json) if pos_json.endswith('.json')]
for i in json_files:
    with open(DATA + 'Definitions/'+i) as json_file:
        data = json.load(json_file)
    defdict.update(data)
definitions = list(defdict.keys())
defvalues = list(defdict.values())


STOPWORDS = set(
    stopwords.words('english') +\
    ['mm', 'section', 'subsection', 'schedule', '-PRON-', 'chapter', 'regulation', 'repealed', 'thereto','unpublishe', 'thereunder','guideline', 'reference','onus','make','Page','Securities','Exchange','India'])

with open(DATA + 'glossary.json') as f:
    glossary = json.load(f)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
DATA = "data/"
docs = ["Issue and Listing of Non Convertible Redeemable Preference Shares", "Investment Advisers", "Depositories and Participants", "Mutual Funds", "Employees Service", "Substantial Acquisition of Shares and Takeovers", "Appointment of Administrator and Procedure for Refunding to the Investors", "Prohibition of Fraudulent and Unfair Trade Practices relating to Securities Market", "Know Your Client Regulations", "Prohibition of Insider Trading", "Merchant Bankers", "Issue and Listing  of Securities Debt Instruments and Security Receipts", "Delisting of Equity Shares","Issue of Capital And Disclosure Requirements2", "Foreign Venture Capital Investor", "Procedure for Board Meetings", "Custodian", "Ombudsman", "Investor Protection and Education Fund", "Foreign Portfolio Investors", "Issue of Sweat Equity", "Collective Investment Scheme", "Portfolio Managers", "Research Analysts", "Procedure for Search and Seizure", "Issue of Capital And Disclosure Requirements", "Share Based Employee Benefits", "Debenture Trustees", "Alternative Investment Funds", "Stock Exchanges and Clearing Corporations", "Self Regulatory Organisations", "Settlement Proceedings", "Issues and Listing of Muncipal Debt Securities", "Buy Back Of Securities2","Issue and Listing of Debt Securities", "Infrastructure Investment Trusts", "Stock Brokers", "Listing Obligations and Disclosure Requirements", "Registrars to an Issue and Share Transfer Agents", "Real Estate Investment Trusts", "Intermediaries", "Certification of Associated Persons in the Securities Markets", "Credit Rating Agencies", "Regulatory Fee on Stock Exchanges", "Underwriters", "Buy Back Of Securities", "Bankers to an Issue", "Central Database of Market Participants"]
with open(DATA + 'cleanedregulations48.pkl','rb') as f:
    docregs = pickle.load(f)    

regMap = dict()
for key,val in zip(docs,docregs):
  regMap[key]=val
# Out:
# ['Issue and Listing of Non Convertible Redeemable Preference Shares',
#  'Investment Advisers',
#  'Depositories and Participants',
#  'Mutual Funds',
#  'Employees Service',
#  'Substantial Acquisition of Shares and Takeovers',
#  'Appointment of Administrator and Procedure for Refunding to the Investors',
#  'Prohibition of Fraudulent and Unfair Trade Practices relating to Securities Market',
#  'Know Your Client Regulations',
#  'Prohibition of Insider Trading',
#  'Merchant Bankers',
#  'Issue and Listing  of Securities Debt Instruments and Security Receipts',
#  'Delisting of Equity Shares',
#  'Issue of Capital And Disclosure Requirements2',
#  'Foreign Venture Capital Investor',
#  'Procedure for Board Meetings',
#  'Custodian',
#  'Ombudsman',
#  'Investor Protection and Education Fund',
#  'Foreign Portfolio Investors',
#  'Issue of Sweat Equity',
#  'Collective Investment Scheme',
#  'Portfolio Managers',
#  'Research Analysts',
#  'Procedure for Search and Seizure',
#  'Issue of Capital And Disclosure Requirements',
#  'Share Based Employee Benefits',
#  'Debenture Trustees',
#  'Alternative Investment Funds',
#  'Stock Exchanges and Clearing Corporations',
#  'Self Regulatory Organisations',
#  'Settlement Proceedings',
#  'Issues and Listing of Muncipal Debt Securities',
#  'Buy Back Of Securities2',
#  'Issue and Listing of Debt Securities',
#  'Infrastructure Investment Trusts',
#  'Stock Brokers',
#  'Listing Obligations and Disclosure Requirements',
#  'Registrars to an Issue and Share Transfer Agents',
#  'Real Estate Investment Trusts',
#  'Intermediaries',
#  'Certification of Associated Persons in the Securities Markets',
#  'Credit Rating Agencies',
#  'Regulatory Fee on Stock Exchanges',
#  'Underwriters',
#  'Buy Back Of Securities',
#  'Bankers to an Issue',
#  'Central Database of Market Participants']

# %%
path_to_json = DATA + 'Definitions/'
json_files = [pos_json for pos_json in os.listdir(path_to_json) if pos_json.endswith('.json')]
for i in json_files:
    with open(DATA + 'Definitions/'+i) as json_file:
        data = json.load(json_file)

    regMap[i.split(".json")[0]] = [ k+v for k,v in data.items() ] + regMap[i.split(".json")[0]]

# %%
docregs = list(regMap.values())

with open(DATA + 'cleanedregulations48.pkl','wb') as f:
    pickle.dump(docregs,f)

# %%
# !zip -r pipeline.zip data
# !mv pipeline.zip /content/drive/MyDrive/CollabData/
# Out:
#   adding: data/ (stored 0%)
#   adding: data/misc_DF_new.json (deflated 83%)
#   adding: data/legal_filenames_testing.pkl (deflated 81%)
#   adding: data/informal_queries.pkl (deflated 74%)
#   adding: data/finaltrain.pkl (deflated 73%)
#   adding: data/misc_tf_idf.pkl (deflated 85%)
#   adding: data/misc_total_vocab_new.pkl (deflated 60%)
#   adding: data/case_origreg.pkl (deflated 75%)
#   adding: data/misc_tf_idf.json (stored 0%)
#   adding: data/QnA_version1/ (stored 0%)
#   adding: data/QnA_version1/case_origreg.pkl (deflated 75%)
#   adding: data/QnA_version1/misc_origreg.pkl (deflated 75%)
#   adding: data/cleanedregtopics48.pkl (deflated 59%)
#   adding: data/misc_origreg.pkl (deflated 75%)
#   adding: data/trainquery.pkl (deflated 75%)
#   adding: data/case_total_vocab_new.pkl (deflated 56%)
#   adding: data/case_queries.pkl (deflated 75%)
#   adding: data/misc_filenames_testing.pkl (deflated 52%)
#   adding: data/misc_origreg_new.pkl (deflated 75%)
#   adding: data/cleanedregulations48.pkl (deflated 75%)
#   adding: data/misc_tf_idf_new.pkl (deflated 70%)
#   adding: data/case_origreg_new.pkl (deflated 75%)
#   adding: data/informal_sentences.pkl (deflated 70%)
#   adding: data/case_sentences.pkl (deflated 74%)
#   adding: data/case_tf_idf_new.pkl (deflated 70%)
#   adding: data/informal_text.pkl (deflated 71%)
#   adding: data/casevocab.pkl (deflated 56%)
#   adding: data/misc_origreg_testing.pkl (deflated 75%)
#   adding: data/concept_queries.pkl (deflated 74%)
#   adding: data/vocabdef.pkl (deflated 50%)
#   adding: data/case_DF_new.json (deflated 74%)
#   adding: data/case_filenames.pkl (deflated 62%)
#   adding: data/misc_total_vocab.pkl (deflated 60%)
#   adding: data/mainvocab.pkl (deflated 50%)
#   adding: data/miscfiles_mapper.pkl (deflated 74%)
#   adding: data/case_DF.json (deflated 64%)
#   adding: data/miscvocab.pkl (deflated 59%)
#   adding: data/case_total_vocab.pkl (deflated 56%)
#   adding: data/legal_origreg_testing.pkl (deflated 75%)
#   adding: data/casefiles_mapper.pkl (deflated 75%)
#   adding: data/new_cleanedregulations48.pkl (deflated 74%)
#   adding: data/README.md (deflated 54%)
#   adding: data/tfidf_regs.pkl (deflated 66%)
#   adding: data/concept_sentences.pkl (deflated 75%)
#   adding: data/glossary.json (deflated 74%)
#   adding: data/misc_DF.json (deflated 81%)
#   adding: data/Definitions/ (stored 0%)
#   adding: data/Definitions/Issue and Listing of Non Convertible Redeemable Preference Shares.json (deflated 65%)
#   adding: data/Definitions/Merchant Bankers.json (deflated 61%)
#   adding: data/Definitions/Listing Obligations and Disclosure Requirements.json (deflated 72%)
#   adding: data/Definitions/Portfolio Managers.json (deflated 61%)
#   adding: data/Definitions/Ombudsman.json (deflated 59%)
#   adding: data/Definitions/Foreign Portfolio Investors.json (deflated 61%)
#   adding: data/Definitions/Procedure for Search and Seizure.json (deflated 54%)
#   adding: data/Definitions/Depositories and Participants.json (deflated 64%)
#   adding: data/Definitions/Procedure for Board Meetings.json (deflated 51%)
#   adding: data/Definitions/Know Your Client Regulations.json (deflated 58%)
#   adding: data/Definitions/Credit Rating Agencies.json (deflated 63%)
#   adding: data/Definitions/Registrars to an Issue and Share Transfer Agents.json (deflated 66%)
#   adding: data/Definitions/Investment Advisers.json (deflated 59%)
#   adding: data/Definitions/Certification of Associated Persons in the Securities Markets.json (deflated 57%)
#   adding: data/Definitions/Alternative Investment Funds.json (deflated 69%)
#   adding: data/Definitions/Issue and Listing  of Securities Debt Instruments and Security Receipts.json (deflated 65%)
#   adding: data/Definitions/Regulatory Fee on Stock Exchanges.json (deflated 58%)
#   adding: data/Definitions/Settlement Proceedings.json (deflated 60%)
#   adding: data/Definitions/Substantial Acquisition of Shares and Takeovers.json (deflated 69%)
#   adding: data/Definitions/Employees Service.json (deflated 64%)
#   adding: data/Definitions/Intermediaries.json (deflated 61%)
#   adding: data/Definitions/Custodian.json (deflated 76%)
#   adding: data/Definitions/Self Regulatory Organisations.json (deflated 67%)
#   adding: data/Definitions/Bankers to an Issue.json (deflated 59%)
#   adding: data/Definitions/Stock Exchanges and Clearing Corporations.json (deflated 66%)
#   adding: data/Definitions/.ipynb_checkpoints/ (stored 0%)
#   adding: data/Definitions/Prohibition of Fraudulent and Unfair Trade Practices relating to Securities Market.json (deflated 58%)
#   adding: data/Definitions/README.md (deflated 43%)
#   adding: data/Definitions/Issue of Capital And Disclosure Requirements.json (deflated 65%)
#   adding: data/Definitions/Issues and Listing of Muncipal Debt Securities.json (deflated 68%)
#   adding: data/Definitions/Prohibition of Insider Trading.json (deflated 66%)
#   adding: data/Definitions/Investor Protection and Education Fund.json (deflated 52%)
#   adding: data/Definitions/Stock Brokers.json (deflated 70%)
#   adding: data/concept_text.pkl (deflated 77%)
#   adding: data/informal_filenames.pkl (deflated 47%)
#   adding: data/case_tf_idf.pkl (deflated 66%)
#   adding: data/case_text.pkl (deflated 75%)
#   adding: data/casefiles_sentences_new.pkl (deflated 75%)
#   adding: data/concept_filenames.pkl (deflated 58%)
#   adding: data/reg_topics.pkl (deflated 70%)

# %%
defdict["designated securities"]
what is designated securities

designated securities means specified securities, non-convertible debt securities, non-convertible redeemable preference shares, perpetual debt instrument, perpetual non-cumulative preference shares, Indian depository receipts, securitised debt instruments, [security receipts,]1 units issued by mutual funds and any other securities as may be specified by the Board
# Out:
# ' means specified securities, non-convertible debt securities, non-convertible redeemable preference shares, perpetual debt instrument, perpetual non-cumulative preference shares, Indian depository receipts, securitised debt instruments, [security receipts,]1 units issued by mutual funds and any other securities as may be specified by the Board ; (i)'

# %%
def queryvocab(query):
    question_words = ["What","When","Where","Why","How","Who"]
    REMOVE_WORDS = ['regulations','rules','rule','chapter','section','sub','SEBI','means','shall','Securities','Exchange',
                    'pertaining','India']
    qvocab=[i for i in query.split() if i not in stopwords.words() + REMOVE_WORDS
            + question_words]
            
    return qvocab, " ".join(qvocab)

# %%
def querypreprocess(query, qvocab, definitions, finaltopics):        
    qnew = " ".join(qvocab)

    importantwords = [ i for i in qvocab if i in definitions]

    expansionwords = []

    for i in qvocab:
      for j in finaltopics:
        if i in j:
          if i not in importantwords:
            importantwords.append(i)
          else:
              if i in definitions:
                  expansionwords.append(i)
    

    for i in expansionwords:
        if i in definitions:
          k=definitions.index(i)
          s = i
          s = s + defvalues[k]
          qnew = qnew + ' ' + s
        else:
          qnew = qnew + ' ' + i
    query = qnew
    
    sent = nlp(query)
    t=0
    for token in sent:
        if(str(token) in importantwords):
            if(t!=0):
                if(str(sent[t-1]) not in importantwords):
                    importantwords.append(str(sent[t-1]))
            if(token.tag_ == 'VB'):
                importantwords.append(str(token))
        t+=1
    
    return query, qvocab, importantwords, expansionwords

# %%
with open(DATA + 'cleanedregtopics48.pkl','rb') as f:
    finaltopics = pickle.load(f)    
#vocab definitions
with open(DATA + 'mainvocab.pkl','rb') as f:
    mainvocab = pickle.load(f) 

with open(DATA + 'vocabdef.pkl','rb') as f:
    vocabdef = pickle.load(f)

# %%
from haystack.pipelines import DocumentSearchPipeline

reg_doc_retrieval = DocumentSearchPipeline(reg_retriever)
legal_doc_retrieval = DocumentSearchPipeline(legal_retriever)
misc_doc_retrieval = DocumentSearchPipeline(misc_retriever)

# %%
limit=16

# %%
from tqdm import tqdm
data=dict()
data["question"]=list()

data["context"]=list()
data["answer"]=list()


for i in range(1,limit):
  data["rank{}".format(i)]=list()

fr,fl,fm=0,0,0
tr,tl,tm=0,0,0
for i,r in tqdm(df.iterrows()):
    if r["doc_type"]=="regulations":
      res = reg_doc_retrieval.run(    
          query=r["question"]
          , params={"Retriever": {"top_k": limit-1}}
      )  
      tr+=1
    elif r["doc_type"]=="legal case":
      res = legal_doc_retrieval.run(    
          query=r["question"]
          , params={"Retriever": {"top_k": limit-1}}
      )  
      tl+=1
    else:    
      res = misc_doc_retrieval.run(    
          query=r["question"]
          , params={"Retriever": {"top_k": limit-1}}
      )  
      tm+=1

    retrieved_docs = [ d.content for d in res["documents"]]
    flag=True
    for i in range(1,limit):
      data["rank{}".format(i)].append(retrieved_docs[i-1])
      if flag and (r["context"] in retrieved_docs[i-1] or retrieved_docs[i-1] in r["context"]):
        if r["doc_type"]=="regulations":
          fr+=1
        elif r["doc_type"]=="legal case":
          fl+=1
        else:
          fm+=1
        flag=False

    data["question"].append(r["question"])
    data["context"].append(r["context"])
    data["answer"].append(r["Answer Span"])
# Out:
# 103it [00:03, 31.99it/s]

# %%
fr,fl,fm
# Out:
# (3, 12, 0)

# %%
tr,tl,tm
# Out:
# (39, 34, 30)

# %%
fr*100/tr,fl*100/tl,fm*100/tm
# Out:
# (7.6923076923076925, 35.294117647058826, 0.0)

# %%
pd.DataFrame(data).to_csv("nonpreprocessed.csv",index=False)
pd.DataFrame(data)
# Out:
#                                                                             question  ...                                                                           rank15
# 0     Does an innocent recipient of UPSI have any defence under the PIT regulations?  ...  BEFORE THE ADJUDICATING OFFICER SECURITIES AND EXCHANGE BOARD OF INDIA ADJUD...
# 1    Will a promoter group entity require a pre-clearance from a related company ...  ...  BEFORE THE ADJUDICATING OFFICER SECURITIES AND EXCHANGE BOARD OF INDIA ADJUD...
# 2    Is inter-se off-market transfer of shares between insiders within a period o...  ...  BEFORE THE ADJUDICATING OFFICER SECURITIES AND EXCHANGE BOARD OF INDIA [ADJU...
# 3                     Can an AIF invest its unutilized funds in liquid mutual funds?  ...  STTrft 1,61-1fa.f; 1\telSecurities and ExchangeBoard of IndiaDEPUTY GENERAL ...
# 4       What are the penal consequences of not furnishing information asked by SEBI?  ...  BEFORE THE ADJUDICATING OFFICER SECURITIES AND EXCHANGE BOARD OF INDIA [ADJU...
# ..                                                                               ...  ...                                                                              ...
# 98                                                                    What is InvIT?  ...  BEFORE THE ADJUDICATING OFFICER SECURITIES AND EXCHANGE BOARD OF INDIA ADJUD...
# 99                      What does the Section 77A of the Companies Act, 1956 entail?  ...  BEFORE THE ADJUDICATING OFFICER SECURITIES AND EXCHANGE BOARD OF INDIA ADJUD...
# 100                     What does the Section 77A(4) of the Companies Act, 1956 say?  ...  BEFORE THE ADJUDICATING OFFICER SECURITIES AND EXCHANGE BOARD OF INDIA [ADJU...
# 101                     What does the Section 77A(2) of the Companies Act, 1956 say?  ...  BEFORE THE ADJUDICATING OFFICER SECURITIES AND EXCHANGE BOARD OF INDIA [ADJU...
# 102  What does the Section 19(1)(e) of SEBI(Buy back of Securities) regulations, ...  ...  BEFORE THE ADJUDICATING OFFICER SECURITIES AND EXCHANGE BOARD OF INDIA [ADJU...
#
# [103 rows x 18 columns]

# %%
data=dict()
data["question"]=list()

data["context"]=list()
data["answer"]=list()

for i in range(1,limit):
  data["rank{}".format(i)]=list()

for i,r in tqdm(df.iterrows()):
    _,query = queryvocab(r["question"])
    
    data["question"].append(query)

    if r["doc_type"]=="regulations":
      res = reg_doc_retrieval.run(    
          query=query
          , params={"Retriever": {"top_k": limit-1}}
      )  
    elif r["doc_type"]=="legal case":
      res = legal_doc_retrieval.run(    
          query=query
          , params={"Retriever": {"top_k": limit-1}}
      )  
    else:    
      res = misc_doc_retrieval.run(    
          query=query
          , params={"Retriever": {"top_k": limit-1}}
      )  


    retrieved_docs = [ d.content for d in res["documents"]]
    for i in range(1,limit):
      try:
        data["rank{}".format(i)].append(retrieved_docs[i-1])
      except:
        data["rank{}".format(i)].append(" ")
    data["context"].append(r["context"])
    data["answer"].append(r["Answer Span"])
# Out:
# 103it [00:08, 11.67it/s]

# %%
pd.DataFrame(data).to_csv("preprocessed.csv",index=False)
pd.DataFrame(data)
# Out:
#                                                                             question  ...                                                                           rank15
# 0                              Does innocent recipient UPSI defence PIT regulations?  ...  BEFORE THE ADJUDICATING OFFICER SECURITIES AND EXCHANGE BOARD OF INDIA ADJUD...
# 1    Will promoter group entity require pre-clearance related company even though...  ...  BEFORE THE ADJUDICATING OFFICER SECURITIES AND EXCHANGE BOARD OF INDIA ADJUD...
# 2    Is inter-se off-market transfer shares insiders within period 6 months post ...  ...  BEFORE THE SECURITIES AND EXCHANGE BOARD OF INDIA, MUMBAI CORAM: S. RAMAN, W...
# 3                               Can AIF invest unutilized funds liquid mutual funds?  ...  is T1 CF;Kri --UtuAt)Motilal Oswal Real Estate Investment Advisors Pvt. Ltd....
# 4                              penal consequences furnishing information asked SEBI?  ...  3.  (1)  An  application  by  scheduled  bank  for  grant  of  a  certificat...
# ..                                                                               ...  ...                                                                              ...
# 98                                                                            InvIT?  ...
# 99                                           Section 77A Companies Act, 1956 entail?  ...  BEFORE THE ADJUDICATING OFFICER SECURITIES AND EXCHANGE BOARD OF INDIA [ADJU...
# 100                                          Section 77A(4) Companies Act, 1956 say?  ...  BEFORE THE ADJUDICATING OFFICER SECURITIES AND EXCHANGE BOARD OF INDIA [ADJU...
# 101                                          Section 77A(2) Companies Act, 1956 say?  ...  BEFORE THE ADJUDICATING OFFICER SECURITIES AND EXCHANGE BOARD OF INDIA [ ADJ...
# 102                Section 19(1)(e) SEBI(Buy back Securities) regulations, 1998 say?  ...  BEFORE THE ADJUDICATING OFFICER SECURITIES AND EXCHANGE BOARD OF INDIA [ADJU...
#
# [103 rows x 18 columns]

# %%
analysis=dict()
analysis["positive"]=list()
analysis["answer"]=list()
analysis["question"]=list()

for i in range(1,limit):
  analysis["rank{}".format(i)]=list()

# %%
found=0
tempdf = pd.DataFrame(data)
for n,r in tempdf.iterrows():
  for i in range(1,limit):
    if r["context"] in r["rank{}".format(i)] or r["rank{}".format(i)] in r["context"]:
      found+=1

found
# Out:
# 16

# %%
tempdf = pd.DataFrame(data)
for n,r in tempdf.iterrows():
  for i in range(1,limit):
    val=0
    analysis["rank{}".format(i)].append(r["rank{}".format(i)])
    if r["answer"] in r["rank{}".format(i)]:
      val=1
  analysis["positive"].append(val)
  analysis["answer"].append(r["answer"])
  analysis["question"].append(r["question"])

# %%
found=0
tempdf = pd.read_csv("nonpreprocessed.csv")
for n,r in tempdf.iterrows():
  for i in range(1,limit):
    if r["context"] in r["rank{}".format(i)] or r["rank{}".format(i)] in r["context"]:
      print("YES: ",n )
      print(i)
      found+=1
      break
  print("="*5)

found

# %%
tempdf = pd.read_csv("nonpreprocessed.csv")
# tempdf = pd.DataFrame(data)
for n,r in tempdf.iterrows():
  for i in range(1,limit):
    val=0
    analysis["rank{}".format(i)].append(r["rank{}".format(i)])
    if r["answer"] in r["rank{}".format(i)]:
      val=1
  analysis["positive"].append(val)
  analysis["answer"].append(r["answer"])
  analysis["question"].append(r["question"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-84-6d457074df12> in <module>()
#       6   for i in range(1,limit):
#       7     val=0
# ----> 8     analysis["rank{}".format(i)].append(r["rank{}".format(i)])
#       9     if r["answer"] in r["rank{}".format(i)]:
#      10       val=1
#
# NameError: name 'analysis' is not defined

# %%
analysisdf = pd.DataFrame(analysis)

# %%
analysisdf[analysisdf["positive"]==1].head(n=10).to_csv("PositiveRetrievals.csv",index=False)

# %%
analysisdf[analysisdf["positive"]==0].head(n=10).to_csv("NegativeRetrievals.csv",index=False)

# %% [markdown]
# ### FULL PIPELINE

# %%
# query
metric.compute(predictions=formatted_predictions, references=references)
# Without query preprocessing : {'exact_match': 0.0, 'f1': 12.927294976475306}
# With query preprocessing : {'exact_match': 0.0, 'f1': 1.0526315789473686}

# %%
len(references)

# %%
legaldf= df[df["doc_type"]=="legal case"]
formatted_predictions=list()
answeregs=list()
references=list()
itr=0
for i,r in tqdm(legaldf.iterrows()):
    prediction = legal_pipe.run(    
        query=r["question"]
        , params={"Retriever": {"top_k": 15}, "Reader": {"top_k": 1}}
    )  
    references.append({"id": i, "answers": r["answers"]})
    formatted_predictions.append({"id": i, "prediction_text":  prediction["answers"][0].answer})

# %%
metric.compute(predictions=formatted_predictions, references=references)

# %%
legaldf= df[df["doc_type"]=="misc"]
formatted_predictions=list()
answeregs=list()
references=list()
itr=0
for i,r in tqdm(legaldf.iterrows()):
    prediction = legal_pipe.run(    
        query=r["question"]
        , params={"Retriever": {"top_k": 15}, "Reader": {"top_k": 1}}
    )  
    references.append({"id": i, "answers": r["answers"]})
    formatted_predictions.append({"id": i, "prediction_text":  prediction["answers"][0].answer})

# %%
metric.compute(predictions=formatted_predictions, references=references)
